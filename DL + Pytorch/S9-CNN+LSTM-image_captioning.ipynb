# %% [markdown]
# ## download data

# %%
# !pip install pycocotools==2.0.7

import torch
import torchvision
import nltk
import pycocotools

print(torch.__version__)
print(torchvision.__version__)
print(nltk.__version__)
# Out:
# Requirement already satisfied: pycocotools==2.0.7 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from pycocotools==2.0.7) (3.9.0)
# Requirement already satisfied: numpy in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from pycocotools==2.0.7) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (24.0)
# Requirement already satisfied: pillow>=8 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.7) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.1.0->pycocotools==2.0.7) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/mb600l/conda_env/pytorch_GPU_3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0.7) (1.16.0)
# 2.3.0
# 0.18.0
# 3.9.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# linux
# !apt-get install wget
# mac
# !brew install wget
 
# create a data directory
# !mkdir -p data/coco/
 
# download images and annotations to the data directory
#!wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip -P ./data/coco/
#!wget http://images.cocodataset.org/zips/train2014.zip -P ./data/coco/
#!wget http://images.cocodataset.org/zips/val2014.zip -P ./data/coco/
    
# extract zipped images and annotations and remove the zip files
#!unzip ./data/coco/annotations_trainval2014.zip -d ./data/coco/
#!rm ./data/coco/annotations_trainval2014.zip
# !unzip ./data/coco/train2014.zip -d ./data/coco/
#!rm ./data/coco/train2014.zip 
# !unzip ./data/coco/val2014.zip -d ./data/coco/
#!rm ./data/coco/val2014.zip
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# unzip:  cannot find or open ./data/coco/train2014.zip, ./data/coco/train2014.zip.zip or ./data/coco/train2014.zip.ZIP.
# unzip:  cannot find or open ./data/coco/val2014.zip, ./data/coco/val2014.zip.zip or ./data/coco/val2014.zip.ZIP.

# %% [markdown]
# ## import dependencies

# %%
import os
import nltk
import pickle
import numpy as np
from PIL import Image
from collections import Counter
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
 
import torch
import torch.nn as nn
import torch.utils.data as data
from torchvision import transforms
import torchvision.models as models
import torchvision.transforms as transforms
from torch.nn.utils.rnn import pack_padded_sequence

# %%
# nltk.download('punkt')

# %% [markdown]
# ## build vocab

# %%
class Vocab(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.w2i = {}
        self.i2w = {}
        self.index = 0
 
    def __call__(self, token):
        if not token in self.w2i:
            return self.w2i['<unk>']
        return self.w2i[token]
 
    def __len__(self):
        return len(self.w2i)
    def add_token(self, token):
        if not token in self.w2i:
            self.w2i[token] = self.index
            self.i2w[self.index] = token
            self.index += 1

def build_vocabulary(json, threshold):
    """Build a simple vocabulary wrapper."""
    coco = COCO(json)
    counter = Counter()
    ids = coco.anns.keys()
    for i, id in enumerate(ids):
        caption = str(coco.anns[id]['caption'])
        tokens = nltk.tokenize.word_tokenize(caption.lower())
        counter.update(tokens)
 
        if (i+1) % 1000 == 0:
            print("[{}/{}] Tokenized the captions.".format(i+1, len(ids)))
 
    # If the word frequency is less than 'threshold', then the word is discarded.
    tokens = [token for token, cnt in counter.items() if cnt >= threshold]
 
    # Create a vocab wrapper and add some special tokens.
    vocab = Vocab()
    vocab.add_token('<pad>')
    vocab.add_token('<start>')
    vocab.add_token('<end>')
    vocab.add_token('<unk>')
 
    # Add the words to the vocabulary.
    for i, token in enumerate(tokens):
        vocab.add_token(token)
    return vocab
 
vocab = build_vocabulary(json='data/coco/annotations/captions_train2014.json', threshold=4)
vocab_path = './data/coco/vocabulary.pkl'
with open(vocab_path, 'wb') as f:
    pickle.dump(vocab, f)
print("Total vocabulary size: {}".format(len(vocab)))
print("Saved the vocabulary wrapper to '{}'".format(vocab_path))
# Out:
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!
# [1000/414113] Tokenized the captions.
# [2000/414113] Tokenized the captions.
# [3000/414113] Tokenized the captions.
# [4000/414113] Tokenized the captions.
# [5000/414113] Tokenized the captions.
# [6000/414113] Tokenized the captions.
# [7000/414113] Tokenized the captions.
# [8000/414113] Tokenized the captions.
# [9000/414113] Tokenized the captions.
# [10000/414113] Tokenized the captions.
# [11000/414113] Tokenized the captions.
# [12000/414113] Tokenized the captions.
# [13000/414113] Tokenized the captions.
# [14000/414113] Tokenized the captions.
# [15000/414113] Tokenized the captions.
# [16000/414113] Tokenized the captions.
# [17000/414113] Tokenized the captions.
# [18000/414113] Tokenized the captions.
# [19000/414113] Tokenized the captions.
# [20000/414113] Tokenized the captions.
# [21000/414113] Tokenized the captions.
# [22000/414113] Tokenized the captions.
# [23000/414113] Tokenized the captions.
# [24000/414113] Tokenized the captions.
# [25000/414113] Tokenized the captions.
# [26000/414113] Tokenized the captions.
# [27000/414113] Tokenized the captions.
# [28000/414113] Tokenized the captions.
# [29000/414113] Tokenized the captions.
# [30000/414113] Tokenized the captions.
# [31000/414113] Tokenized the captions.
# [32000/414113] Tokenized the captions.
# [33000/414113] Tokenized the captions.
# [34000/414113] Tokenized the captions.
# [35000/414113] Tokenized the captions.
# [36000/414113] Tokenized the captions.
# [37000/414113] Tokenized the captions.
# [38000/414113] Tokenized the captions.
# [39000/414113] Tokenized the captions.
# [40000/414113] Tokenized the captions.
# [41000/414113] Tokenized the captions.
# [42000/414113] Tokenized the captions.
# [43000/414113] Tokenized the captions.
# [44000/414113] Tokenized the captions.
# [45000/414113] Tokenized the captions.
# [46000/414113] Tokenized the captions.
# [47000/414113] Tokenized the captions.
# [48000/414113] Tokenized the captions.
# [49000/414113] Tokenized the captions.
# [50000/414113] Tokenized the captions.
# [51000/414113] Tokenized the captions.
# [52000/414113] Tokenized the captions.
# [53000/414113] Tokenized the captions.
# [54000/414113] Tokenized the captions.
# [55000/414113] Tokenized the captions.
# [56000/414113] Tokenized the captions.
# [57000/414113] Tokenized the captions.
# [58000/414113] Tokenized the captions.
# [59000/414113] Tokenized the captions.
# [60000/414113] Tokenized the captions.
# [61000/414113] Tokenized the captions.
# [62000/414113] Tokenized the captions.
# [63000/414113] Tokenized the captions.
# [64000/414113] Tokenized the captions.
# [65000/414113] Tokenized the captions.
# [66000/414113] Tokenized the captions.
# [67000/414113] Tokenized the captions.
# [68000/414113] Tokenized the captions.
# [69000/414113] Tokenized the captions.
# [70000/414113] Tokenized the captions.
# [71000/414113] Tokenized the captions.
# [72000/414113] Tokenized the captions.
# [73000/414113] Tokenized the captions.
# [74000/414113] Tokenized the captions.
# [75000/414113] Tokenized the captions.
# [76000/414113] Tokenized the captions.
# [77000/414113] Tokenized the captions.
# [78000/414113] Tokenized the captions.
# [79000/414113] Tokenized the captions.
# [80000/414113] Tokenized the captions.
# [81000/414113] Tokenized the captions.
# [82000/414113] Tokenized the captions.
# [83000/414113] Tokenized the captions.
# [84000/414113] Tokenized the captions.
# [85000/414113] Tokenized the captions.
# [86000/414113] Tokenized the captions.
# [87000/414113] Tokenized the captions.
# [88000/414113] Tokenized the captions.
# [89000/414113] Tokenized the captions.
# [90000/414113] Tokenized the captions.
# [91000/414113] Tokenized the captions.
# [92000/414113] Tokenized the captions.
# [93000/414113] Tokenized the captions.
# [94000/414113] Tokenized the captions.
# [95000/414113] Tokenized the captions.
# [96000/414113] Tokenized the captions.
# [97000/414113] Tokenized the captions.
# [98000/414113] Tokenized the captions.
# [99000/414113] Tokenized the captions.
# [100000/414113] Tokenized the captions.
# [101000/414113] Tokenized the captions.
# [102000/414113] Tokenized the captions.
# [103000/414113] Tokenized the captions.
# [104000/414113] Tokenized the captions.
# [105000/414113] Tokenized the captions.
# [106000/414113] Tokenized the captions.
# [107000/414113] Tokenized the captions.
# [108000/414113] Tokenized the captions.
# [109000/414113] Tokenized the captions.
# [110000/414113] Tokenized the captions.
# [111000/414113] Tokenized the captions.
# [112000/414113] Tokenized the captions.
# [113000/414113] Tokenized the captions.
# [114000/414113] Tokenized the captions.
# [115000/414113] Tokenized the captions.
# [116000/414113] Tokenized the captions.
# [117000/414113] Tokenized the captions.
# [118000/414113] Tokenized the captions.
# [119000/414113] Tokenized the captions.
# [120000/414113] Tokenized the captions.
# [121000/414113] Tokenized the captions.
# [122000/414113] Tokenized the captions.
# [123000/414113] Tokenized the captions.
# [124000/414113] Tokenized the captions.
# [125000/414113] Tokenized the captions.
# [126000/414113] Tokenized the captions.
# [127000/414113] Tokenized the captions.
# [128000/414113] Tokenized the captions.
# [129000/414113] Tokenized the captions.
# [130000/414113] Tokenized the captions.
# [131000/414113] Tokenized the captions.
# [132000/414113] Tokenized the captions.
# [133000/414113] Tokenized the captions.
# [134000/414113] Tokenized the captions.
# [135000/414113] Tokenized the captions.
# [136000/414113] Tokenized the captions.
# [137000/414113] Tokenized the captions.
# [138000/414113] Tokenized the captions.
# [139000/414113] Tokenized the captions.
# [140000/414113] Tokenized the captions.
# [141000/414113] Tokenized the captions.
# [142000/414113] Tokenized the captions.
# [143000/414113] Tokenized the captions.
# [144000/414113] Tokenized the captions.
# [145000/414113] Tokenized the captions.
# [146000/414113] Tokenized the captions.
# [147000/414113] Tokenized the captions.
# [148000/414113] Tokenized the captions.
# [149000/414113] Tokenized the captions.
# [150000/414113] Tokenized the captions.
# [151000/414113] Tokenized the captions.
# [152000/414113] Tokenized the captions.
# [153000/414113] Tokenized the captions.
# [154000/414113] Tokenized the captions.
# [155000/414113] Tokenized the captions.
# [156000/414113] Tokenized the captions.
# [157000/414113] Tokenized the captions.
# [158000/414113] Tokenized the captions.
# [159000/414113] Tokenized the captions.
# [160000/414113] Tokenized the captions.
# [161000/414113] Tokenized the captions.
# [162000/414113] Tokenized the captions.
# [163000/414113] Tokenized the captions.
# [164000/414113] Tokenized the captions.
# [165000/414113] Tokenized the captions.
# [166000/414113] Tokenized the captions.
# [167000/414113] Tokenized the captions.
# [168000/414113] Tokenized the captions.
# [169000/414113] Tokenized the captions.
# [170000/414113] Tokenized the captions.
# [171000/414113] Tokenized the captions.
# [172000/414113] Tokenized the captions.
# [173000/414113] Tokenized the captions.
# [174000/414113] Tokenized the captions.
# [175000/414113] Tokenized the captions.
# [176000/414113] Tokenized the captions.
# [177000/414113] Tokenized the captions.
# [178000/414113] Tokenized the captions.
# [179000/414113] Tokenized the captions.
# [180000/414113] Tokenized the captions.
# [181000/414113] Tokenized the captions.
# [182000/414113] Tokenized the captions.
# [183000/414113] Tokenized the captions.
# [184000/414113] Tokenized the captions.
# [185000/414113] Tokenized the captions.
# [186000/414113] Tokenized the captions.
# [187000/414113] Tokenized the captions.
# [188000/414113] Tokenized the captions.
# [189000/414113] Tokenized the captions.
# [190000/414113] Tokenized the captions.
# [191000/414113] Tokenized the captions.
# [192000/414113] Tokenized the captions.
# [193000/414113] Tokenized the captions.
# [194000/414113] Tokenized the captions.
# [195000/414113] Tokenized the captions.
# [196000/414113] Tokenized the captions.
# [197000/414113] Tokenized the captions.
# [198000/414113] Tokenized the captions.
# [199000/414113] Tokenized the captions.
# [200000/414113] Tokenized the captions.
# [201000/414113] Tokenized the captions.
# [202000/414113] Tokenized the captions.
# [203000/414113] Tokenized the captions.
# [204000/414113] Tokenized the captions.
# [205000/414113] Tokenized the captions.
# [206000/414113] Tokenized the captions.
# [207000/414113] Tokenized the captions.
# [208000/414113] Tokenized the captions.
# [209000/414113] Tokenized the captions.
# [210000/414113] Tokenized the captions.
# [211000/414113] Tokenized the captions.
# [212000/414113] Tokenized the captions.
# [213000/414113] Tokenized the captions.
# [214000/414113] Tokenized the captions.
# [215000/414113] Tokenized the captions.
# [216000/414113] Tokenized the captions.
# [217000/414113] Tokenized the captions.
# [218000/414113] Tokenized the captions.
# [219000/414113] Tokenized the captions.
# [220000/414113] Tokenized the captions.
# [221000/414113] Tokenized the captions.
# [222000/414113] Tokenized the captions.
# [223000/414113] Tokenized the captions.
# [224000/414113] Tokenized the captions.
# [225000/414113] Tokenized the captions.
# [226000/414113] Tokenized the captions.
# [227000/414113] Tokenized the captions.
# [228000/414113] Tokenized the captions.
# [229000/414113] Tokenized the captions.
# [230000/414113] Tokenized the captions.
# [231000/414113] Tokenized the captions.
# [232000/414113] Tokenized the captions.
# [233000/414113] Tokenized the captions.
# [234000/414113] Tokenized the captions.
# [235000/414113] Tokenized the captions.
# [236000/414113] Tokenized the captions.
# [237000/414113] Tokenized the captions.
# [238000/414113] Tokenized the captions.
# [239000/414113] Tokenized the captions.
# [240000/414113] Tokenized the captions.
# [241000/414113] Tokenized the captions.
# [242000/414113] Tokenized the captions.
# [243000/414113] Tokenized the captions.
# [244000/414113] Tokenized the captions.
# [245000/414113] Tokenized the captions.
# [246000/414113] Tokenized the captions.
# [247000/414113] Tokenized the captions.
# [248000/414113] Tokenized the captions.
# [249000/414113] Tokenized the captions.
# [250000/414113] Tokenized the captions.
# [251000/414113] Tokenized the captions.
# [252000/414113] Tokenized the captions.
# [253000/414113] Tokenized the captions.
# [254000/414113] Tokenized the captions.
# [255000/414113] Tokenized the captions.
# [256000/414113] Tokenized the captions.
# [257000/414113] Tokenized the captions.
# [258000/414113] Tokenized the captions.
# [259000/414113] Tokenized the captions.
# [260000/414113] Tokenized the captions.
# [261000/414113] Tokenized the captions.
# [262000/414113] Tokenized the captions.
# [263000/414113] Tokenized the captions.
# [264000/414113] Tokenized the captions.
# [265000/414113] Tokenized the captions.
# [266000/414113] Tokenized the captions.
# [267000/414113] Tokenized the captions.
# [268000/414113] Tokenized the captions.
# [269000/414113] Tokenized the captions.
# [270000/414113] Tokenized the captions.
# [271000/414113] Tokenized the captions.
# [272000/414113] Tokenized the captions.
# [273000/414113] Tokenized the captions.
# [274000/414113] Tokenized the captions.
# [275000/414113] Tokenized the captions.
# [276000/414113] Tokenized the captions.
# [277000/414113] Tokenized the captions.
# [278000/414113] Tokenized the captions.
# [279000/414113] Tokenized the captions.
# [280000/414113] Tokenized the captions.
# [281000/414113] Tokenized the captions.
# [282000/414113] Tokenized the captions.
# [283000/414113] Tokenized the captions.
# [284000/414113] Tokenized the captions.
# [285000/414113] Tokenized the captions.
# [286000/414113] Tokenized the captions.
# [287000/414113] Tokenized the captions.
# [288000/414113] Tokenized the captions.
# [289000/414113] Tokenized the captions.
# [290000/414113] Tokenized the captions.
# [291000/414113] Tokenized the captions.
# [292000/414113] Tokenized the captions.
# [293000/414113] Tokenized the captions.
# [294000/414113] Tokenized the captions.
# [295000/414113] Tokenized the captions.
# [296000/414113] Tokenized the captions.
# [297000/414113] Tokenized the captions.
# [298000/414113] Tokenized the captions.
# [299000/414113] Tokenized the captions.
# [300000/414113] Tokenized the captions.
# [301000/414113] Tokenized the captions.
# [302000/414113] Tokenized the captions.
# [303000/414113] Tokenized the captions.
# [304000/414113] Tokenized the captions.
# [305000/414113] Tokenized the captions.
# [306000/414113] Tokenized the captions.
# [307000/414113] Tokenized the captions.
# [308000/414113] Tokenized the captions.
# [309000/414113] Tokenized the captions.
# [310000/414113] Tokenized the captions.
# [311000/414113] Tokenized the captions.
# [312000/414113] Tokenized the captions.
# [313000/414113] Tokenized the captions.
# [314000/414113] Tokenized the captions.
# [315000/414113] Tokenized the captions.
# [316000/414113] Tokenized the captions.
# [317000/414113] Tokenized the captions.
# [318000/414113] Tokenized the captions.
# [319000/414113] Tokenized the captions.
# [320000/414113] Tokenized the captions.
# [321000/414113] Tokenized the captions.
# [322000/414113] Tokenized the captions.
# [323000/414113] Tokenized the captions.
# [324000/414113] Tokenized the captions.
# [325000/414113] Tokenized the captions.
# [326000/414113] Tokenized the captions.
# [327000/414113] Tokenized the captions.
# [328000/414113] Tokenized the captions.
# [329000/414113] Tokenized the captions.
# [330000/414113] Tokenized the captions.
# [331000/414113] Tokenized the captions.
# [332000/414113] Tokenized the captions.
# [333000/414113] Tokenized the captions.
# [334000/414113] Tokenized the captions.
# [335000/414113] Tokenized the captions.
# [336000/414113] Tokenized the captions.
# [337000/414113] Tokenized the captions.
# [338000/414113] Tokenized the captions.
# [339000/414113] Tokenized the captions.
# [340000/414113] Tokenized the captions.
# [341000/414113] Tokenized the captions.
# [342000/414113] Tokenized the captions.
# [343000/414113] Tokenized the captions.
# [344000/414113] Tokenized the captions.
# [345000/414113] Tokenized the captions.
# [346000/414113] Tokenized the captions.
# [347000/414113] Tokenized the captions.
# [348000/414113] Tokenized the captions.
# [349000/414113] Tokenized the captions.
# [350000/414113] Tokenized the captions.
# [351000/414113] Tokenized the captions.
# [352000/414113] Tokenized the captions.
# [353000/414113] Tokenized the captions.
# [354000/414113] Tokenized the captions.
# [355000/414113] Tokenized the captions.
# [356000/414113] Tokenized the captions.
# [357000/414113] Tokenized the captions.
# [358000/414113] Tokenized the captions.
# [359000/414113] Tokenized the captions.
# [360000/414113] Tokenized the captions.
# [361000/414113] Tokenized the captions.
# [362000/414113] Tokenized the captions.
# [363000/414113] Tokenized the captions.
# [364000/414113] Tokenized the captions.
# [365000/414113] Tokenized the captions.
# [366000/414113] Tokenized the captions.
# [367000/414113] Tokenized the captions.
# [368000/414113] Tokenized the captions.
# [369000/414113] Tokenized the captions.
# [370000/414113] Tokenized the captions.
# [371000/414113] Tokenized the captions.
# [372000/414113] Tokenized the captions.
# [373000/414113] Tokenized the captions.
# [374000/414113] Tokenized the captions.
# [375000/414113] Tokenized the captions.
# [376000/414113] Tokenized the captions.
# [377000/414113] Tokenized the captions.
# [378000/414113] Tokenized the captions.
# [379000/414113] Tokenized the captions.
# [380000/414113] Tokenized the captions.
# [381000/414113] Tokenized the captions.
# [382000/414113] Tokenized the captions.
# [383000/414113] Tokenized the captions.
# [384000/414113] Tokenized the captions.
# [385000/414113] Tokenized the captions.
# [386000/414113] Tokenized the captions.
# [387000/414113] Tokenized the captions.
# [388000/414113] Tokenized the captions.
# [389000/414113] Tokenized the captions.
# [390000/414113] Tokenized the captions.
# [391000/414113] Tokenized the captions.
# [392000/414113] Tokenized the captions.
# [393000/414113] Tokenized the captions.
# [394000/414113] Tokenized the captions.
# [395000/414113] Tokenized the captions.
# [396000/414113] Tokenized the captions.
# [397000/414113] Tokenized the captions.
# [398000/414113] Tokenized the captions.
# [399000/414113] Tokenized the captions.
# [400000/414113] Tokenized the captions.
# [401000/414113] Tokenized the captions.
# [402000/414113] Tokenized the captions.
# [403000/414113] Tokenized the captions.
# [404000/414113] Tokenized the captions.
# [405000/414113] Tokenized the captions.
# [406000/414113] Tokenized the captions.
# [407000/414113] Tokenized the captions.
# [408000/414113] Tokenized the captions.
# [409000/414113] Tokenized the captions.
# [410000/414113] Tokenized the captions.
# [411000/414113] Tokenized the captions.
# [412000/414113] Tokenized the captions.
# [413000/414113] Tokenized the captions.
# [414000/414113] Tokenized the captions.
# Total vocabulary size: 9948
# Saved the vocabulary wrapper to './data/coco/vocabulary.pkl'

# %% [markdown]
# ## resize images

# %%
def reshape_image(image, shape):
    """Resize an image to the given shape."""
    return image.resize(shape, Image.LANCZOS)
 
def reshape_images(image_path, output_path, shape):
    """Reshape the images in 'image_path' and save into 'output_path'."""
    if not os.path.exists(output_path):
        os.makedirs(output_path)
 
    images = os.listdir(image_path)
    num_im = len(images)
    for i, im in enumerate(images):
        with open(os.path.join(image_path, im), 'r+b') as f:
            with Image.open(f) as image:
                image = reshape_image(image, shape)
                image.save(os.path.join(output_path, im), image.format)
        if (i+1) % 100 == 0:
            print ("[{}/{}] Resized the images and saved into '{}'."
                   .format(i+1, num_im, output_path))

image_path = './data/coco/train2014/'
output_path = './data/coco/resized_images/'
image_shape = [256, 256]
#reshape_images(image_path, output_path, image_shape)

# %% [markdown]
# ## instantiate data loader

# %%
class CustomCocoDataset(data.Dataset):
    """COCO Custom Dataset compatible with torch.utils.data.DataLoader."""
    def __init__(self, data_path, coco_json_path, vocabulary, transform=None):
        """Set the path for images, captions and vocabulary wrapper.
        
        Args:
            root: image directory.
            json: coco annotation file path.
            vocab: vocabulary wrapper.
            transform: image transformer.
        """
        self.root = data_path
        self.coco_data = COCO(coco_json_path)
        self.indices = list(self.coco_data.anns.keys())
        self.vocabulary = vocabulary
        self.transform = transform
 
    def __getitem__(self, idx):
        """Returns one data pair (image and caption)."""
        coco_data = self.coco_data
        vocabulary = self.vocabulary
        annotation_id = self.indices[idx]
        caption = coco_data.anns[annotation_id]['caption']
        image_id = coco_data.anns[annotation_id]['image_id']
        image_path = coco_data.loadImgs(image_id)[0]['file_name']
 
        image = Image.open(os.path.join(self.root, image_path)).convert('RGB')
        if self.transform is not None:
            image = self.transform(image)
 
        # Convert caption (string) to word ids.
        word_tokens = nltk.tokenize.word_tokenize(str(caption).lower())
        caption = []
        caption.append(vocabulary('<start>'))
        caption.extend([vocabulary(token) for token in word_tokens])
        caption.append(vocabulary('<end>'))
        ground_truth = torch.Tensor(caption)
        return image, ground_truth
 
    def __len__(self):
        return len(self.indices)
 
 
def collate_function(data_batch):
    """Creates mini-batch tensors from the list of tuples (image, caption).
    
    We should build custom collate_fn rather than using default collate_fn, 
    because merging caption (including padding) is not supported in default.
    Args:
        data: list of tuple (image, caption). 
            - image: torch tensor of shape (3, 256, 256).
            - caption: torch tensor of shape (?); variable length.
    Returns:
        images: torch tensor of shape (batch_size, 3, 256, 256).
        targets: torch tensor of shape (batch_size, padded_length).
        lengths: list; valid length for each padded caption.
    """
    # Sort a data list by caption length (descending order).
    data_batch.sort(key=lambda d: len(d[1]), reverse=True)
    imgs, caps = zip(*data_batch)
 
    # Merge images (from list of 3D tensors to 4D tensor).
    # Originally, imgs is a list of <batch_size> number of RGB images with dimensions (3, 256, 256)
    # This line of code turns it into a single tensor of dimensions (<batch_size>, 3, 256, 256)
    imgs = torch.stack(imgs, 0)
 
    # Merge captions (from list of 1D tensors to 2D tensor), similar to merging of images donw above.
    cap_lens = [len(cap) for cap in caps]
    tgts = torch.zeros(len(caps), max(cap_lens)).long()
    for i, cap in enumerate(caps):
        end = cap_lens[i]
        tgts[i, :end] = cap[:end]        
    return imgs, tgts, cap_lens
 
def get_loader(data_path, coco_json_path, vocabulary, transform, batch_size, shuffle):
    """Returns torch.utils.data.DataLoader for custom coco dataset."""
    # COCO caption dataset
    coco_dataset = CustomCocoDataset(data_path=data_path,
                       coco_json_path=coco_json_path,
                       vocabulary=vocabulary,
                       transform=transform)
    
    # Data loader for COCO dataset
    # This will return (images, captions, lengths) for each iteration.
    # images: a tensor of shape (batch_size, 3, 224, 224).
    # captions: a tensor of shape (batch_size, padded_length).
    # lengths: a list indicating valid length for each caption. length is (batch_size).
    custom_data_loader = torch.utils.data.DataLoader(dataset=coco_dataset, 
                                              batch_size=batch_size,
                                              shuffle=shuffle,
                                              collate_fn=collate_function)
    return custom_data_loader

# %% [markdown]
# ## model definition

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_size):
        """Load the pretrained ResNet-152 and replace top fc layer."""
        super(CNNModel, self).__init__()
        resnet = models.resnet152(weights='DEFAULT')
        module_list = list(resnet.children())[:-1]      # delete the last fc layer.
        self.resnet_module = nn.Sequential(*module_list)
        self.linear_layer = nn.Linear(resnet.fc.in_features, embedding_size)
        self.batch_norm = nn.BatchNorm1d(embedding_size, momentum=0.01)
        
    def forward(self, input_images):
        """Extract feature vectors from input images."""
        with torch.no_grad():
            resnet_features = self.resnet_module(input_images)
        resnet_features = resnet_features.reshape(resnet_features.size(0), -1)
        final_features = self.batch_norm(self.linear_layer(resnet_features))
        return final_features
 
 
class LSTMModel(nn.Module):
    def __init__(self, embedding_size, hidden_layer_size, vocabulary_size, num_layers, max_seq_len=20):
        """Set the hyper-parameters and build the layers."""
        super(LSTMModel, self).__init__()
        self.embedding_layer = nn.Embedding(vocabulary_size, embedding_size)
        self.lstm_layer = nn.LSTM(embedding_size, hidden_layer_size, num_layers, batch_first=True)
        self.linear_layer = nn.Linear(hidden_layer_size, vocabulary_size)
        self.max_seq_len = max_seq_len
        
    def forward(self, input_features, capts, lens):
        """Decode image feature vectors and generates captions."""
        embeddings = self.embedding_layer(capts)
        embeddings = torch.cat((input_features.unsqueeze(1), embeddings), 1)
        lstm_input = pack_padded_sequence(embeddings, lens, batch_first=True) 
        hidden_variables, _ = self.lstm_layer(lstm_input)
        model_outputs = self.linear_layer(hidden_variables[0])
        return model_outputs
    
    def sample(self, input_features, lstm_states=None):
        """Generate captions for given image features using greedy search."""
        sampled_indices = []
        lstm_inputs = input_features.unsqueeze(1)
        for i in range(self.max_seq_len):
            hidden_variables, lstm_states = self.lstm_layer(lstm_inputs, lstm_states)          # hiddens: (batch_size, 1, hidden_size)
            model_outputs = self.linear_layer(hidden_variables.squeeze(1))            # outputs:  (batch_size, vocab_size)
            _, predicted_outputs = model_outputs.max(1)                        # predicted: (batch_size)
            sampled_indices.append(predicted_outputs)
            lstm_inputs = self.embedding_layer(predicted_outputs)                       # inputs: (batch_size, embed_size)
            lstm_inputs = lstm_inputs.unsqueeze(1)                         # inputs: (batch_size, 1, embed_size)
        sampled_indices = torch.stack(sampled_indices, 1)                # sampled_ids: (batch_size, max_seq_length)
        return sampled_indices

# %% [markdown]
# ## training loop

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Create model directory
if not os.path.exists('models_dir/'):
    os.makedirs('models_dir/')

    
# Image preprocessing, normalization for the pretrained resnet
transform = transforms.Compose([ 
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(), 
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data/coco/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)

    
# Build data loader
custom_data_loader = get_loader('data/coco/resized_images', 'data/coco/annotations/captions_train2014.json', vocabulary, 
                         transform, 128,
                         shuffle=True) 

# Build the models
encoder_model = CNNModel(256).to(device)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1).to(device)
 
    
# Loss and optimizer
loss_criterion = nn.CrossEntropyLoss()
parameters = list(decoder_model.parameters()) + list(encoder_model.linear_layer.parameters()) + list(encoder_model.batch_norm.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.001)


# Train the models
total_num_steps = len(custom_data_loader)
for epoch in range(5):
    for i, (imgs, caps, lens) in enumerate(custom_data_loader):
 
        # Set mini-batch dataset
        imgs = imgs.to(device)
        caps = caps.to(device)
        tgts = pack_padded_sequence(caps, lens, batch_first=True)[0]
 
        # Forward, backward and optimize
        feats = encoder_model(imgs)
        outputs = decoder_model(feats, caps, lens)
        loss = loss_criterion(outputs, tgts)
        decoder_model.zero_grad()
        encoder_model.zero_grad()
        loss.backward()
        optimizer.step()
 
        # Print log info
        if i % 10 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                  .format(epoch, 5, i, total_num_steps, loss.item(), np.exp(loss.item()))) 
 
        # Save the model checkpoints
        if (i+1) % 1000 == 0:
            torch.save(decoder_model.state_dict(), os.path.join(
                'models_dir/', 'decoder-{}-{}.ckpt'.format(epoch+1, i+1)))
            torch.save(encoder_model.state_dict(), os.path.join(
                'models_dir/', 'encoder-{}-{}.ckpt'.format(epoch+1, i+1)))
# Out:
# loading annotations into memory...
# Done (t=0.27s)
# creating index...
# index created!
# Downloading: "https://download.pytorch.org/models/resnet152-f82ba261.pth" to /home/mb600l/.cache/torch/hub/checkpoints/resnet152-f82ba261.pth
# 100%|██████████| 230M/230M [01:44<00:00, 2.31MB/s]
# Epoch [0/5], Step [0/3236], Loss: 9.1973, Perplexity: 9870.5272
# Epoch [0/5], Step [10/3236], Loss: 5.7932, Perplexity: 328.0455
# Epoch [0/5], Step [20/3236], Loss: 5.3177, Perplexity: 203.9086
# Epoch [0/5], Step [30/3236], Loss: 4.8773, Perplexity: 131.2709
# Epoch [0/5], Step [40/3236], Loss: 4.5725, Perplexity: 96.7849
# Epoch [0/5], Step [50/3236], Loss: 4.3771, Perplexity: 79.6060
# Epoch [0/5], Step [60/3236], Loss: 4.1854, Perplexity: 65.7216
# Epoch [0/5], Step [70/3236], Loss: 4.0853, Perplexity: 59.4596
# Epoch [0/5], Step [80/3236], Loss: 4.0144, Perplexity: 55.3927
# Epoch [0/5], Step [90/3236], Loss: 3.7948, Perplexity: 44.4686
# Epoch [0/5], Step [100/3236], Loss: 3.9354, Perplexity: 51.1813
# Epoch [0/5], Step [110/3236], Loss: 3.7379, Perplexity: 42.0094
# Epoch [0/5], Step [120/3236], Loss: 3.8467, Perplexity: 46.8370
# Epoch [0/5], Step [130/3236], Loss: 3.7322, Perplexity: 41.7703
# Epoch [0/5], Step [140/3236], Loss: 3.7206, Perplexity: 41.2888
# Epoch [0/5], Step [150/3236], Loss: 3.5573, Perplexity: 35.0695
# Epoch [0/5], Step [160/3236], Loss: 3.5784, Perplexity: 35.8155
# Epoch [0/5], Step [170/3236], Loss: 3.4713, Perplexity: 32.1785
# Epoch [0/5], Step [180/3236], Loss: 3.4641, Perplexity: 31.9484
# Epoch [0/5], Step [190/3236], Loss: 3.3908, Perplexity: 29.6896
# Epoch [0/5], Step [200/3236], Loss: 3.3247, Perplexity: 27.7910
# Epoch [0/5], Step [210/3236], Loss: 3.3888, Perplexity: 29.6311
# Epoch [0/5], Step [220/3236], Loss: 3.2859, Perplexity: 26.7328
# Epoch [0/5], Step [230/3236], Loss: 3.5854, Perplexity: 36.0685
# Epoch [0/5], Step [240/3236], Loss: 3.3863, Perplexity: 29.5574
# Epoch [0/5], Step [250/3236], Loss: 3.2155, Perplexity: 24.9151
# Epoch [0/5], Step [260/3236], Loss: 3.3358, Perplexity: 28.1008
# Epoch [0/5], Step [270/3236], Loss: 3.3054, Perplexity: 27.2598
# Epoch [0/5], Step [280/3236], Loss: 3.3962, Perplexity: 29.8510
# Epoch [0/5], Step [290/3236], Loss: 3.4346, Perplexity: 31.0177
# Epoch [0/5], Step [300/3236], Loss: 3.2336, Perplexity: 25.3715
# Epoch [0/5], Step [310/3236], Loss: 3.1415, Perplexity: 23.1378
# Epoch [0/5], Step [320/3236], Loss: 3.1459, Perplexity: 23.2397
# Epoch [0/5], Step [330/3236], Loss: 3.1177, Perplexity: 22.5945
# Epoch [0/5], Step [340/3236], Loss: 2.9990, Perplexity: 20.0656
# Epoch [0/5], Step [350/3236], Loss: 3.0204, Perplexity: 20.4989
# Epoch [0/5], Step [360/3236], Loss: 3.1137, Perplexity: 22.5047
# Epoch [0/5], Step [370/3236], Loss: 2.9999, Perplexity: 20.0844
# Epoch [0/5], Step [380/3236], Loss: 3.0012, Perplexity: 20.1090
# Epoch [0/5], Step [390/3236], Loss: 3.0546, Perplexity: 21.2127
# Epoch [0/5], Step [400/3236], Loss: 3.1003, Perplexity: 22.2054
# Epoch [0/5], Step [410/3236], Loss: 2.9585, Perplexity: 19.2685
# Epoch [0/5], Step [420/3236], Loss: 2.9601, Perplexity: 19.3007
# Epoch [0/5], Step [430/3236], Loss: 2.9407, Perplexity: 18.9296
# Epoch [0/5], Step [440/3236], Loss: 2.9295, Perplexity: 18.7180
# Epoch [0/5], Step [450/3236], Loss: 2.8861, Perplexity: 17.9226
# Epoch [0/5], Step [460/3236], Loss: 2.8989, Perplexity: 18.1542
# Epoch [0/5], Step [470/3236], Loss: 2.9460, Perplexity: 19.0296
# Epoch [0/5], Step [480/3236], Loss: 2.9233, Perplexity: 18.6034
# Epoch [0/5], Step [490/3236], Loss: 3.0053, Perplexity: 20.1915
# Epoch [0/5], Step [500/3236], Loss: 2.7641, Perplexity: 15.8643
# Epoch [0/5], Step [510/3236], Loss: 2.9889, Perplexity: 19.8634
# Epoch [0/5], Step [520/3236], Loss: 2.9949, Perplexity: 19.9825
# Epoch [0/5], Step [530/3236], Loss: 2.8549, Perplexity: 17.3733
# Epoch [0/5], Step [540/3236], Loss: 2.7692, Perplexity: 15.9467
# Epoch [0/5], Step [550/3236], Loss: 3.0384, Perplexity: 20.8726
# Epoch [0/5], Step [560/3236], Loss: 2.9142, Perplexity: 18.4333
# Epoch [0/5], Step [570/3236], Loss: 2.9607, Perplexity: 19.3123
# Epoch [0/5], Step [580/3236], Loss: 2.8371, Perplexity: 17.0660
# Epoch [0/5], Step [590/3236], Loss: 2.8107, Perplexity: 16.6217
# Epoch [0/5], Step [600/3236], Loss: 2.8283, Perplexity: 16.9165
# Epoch [0/5], Step [610/3236], Loss: 2.7732, Perplexity: 16.0101
# Epoch [0/5], Step [620/3236], Loss: 2.6798, Perplexity: 14.5824
# Epoch [0/5], Step [630/3236], Loss: 2.7704, Perplexity: 15.9647
# Epoch [0/5], Step [640/3236], Loss: 2.8232, Perplexity: 16.8309
# Epoch [0/5], Step [650/3236], Loss: 2.7436, Perplexity: 15.5436
# Epoch [0/5], Step [660/3236], Loss: 2.8195, Perplexity: 16.7685
# Epoch [0/5], Step [670/3236], Loss: 2.8930, Perplexity: 18.0475
# Epoch [0/5], Step [680/3236], Loss: 2.7515, Perplexity: 15.6665
# Epoch [0/5], Step [690/3236], Loss: 2.7472, Perplexity: 15.5988
# Epoch [0/5], Step [700/3236], Loss: 2.6773, Perplexity: 14.5463
# Epoch [0/5], Step [710/3236], Loss: 2.8311, Perplexity: 16.9647
# Epoch [0/5], Step [720/3236], Loss: 2.6536, Perplexity: 14.2046
# Epoch [0/5], Step [730/3236], Loss: 2.6712, Perplexity: 14.4574
# Epoch [0/5], Step [740/3236], Loss: 2.6890, Perplexity: 14.7176
# Epoch [0/5], Step [750/3236], Loss: 2.7409, Perplexity: 15.5013
# Epoch [0/5], Step [760/3236], Loss: 2.6534, Perplexity: 14.2020
# Epoch [0/5], Step [770/3236], Loss: 2.7782, Perplexity: 16.0901
# Epoch [0/5], Step [780/3236], Loss: 2.5773, Perplexity: 13.1609
# Epoch [0/5], Step [790/3236], Loss: 2.7480, Perplexity: 15.6110
# Epoch [0/5], Step [800/3236], Loss: 2.5929, Perplexity: 13.3687
# Epoch [0/5], Step [810/3236], Loss: 2.6556, Perplexity: 14.2340
# Epoch [0/5], Step [820/3236], Loss: 2.7045, Perplexity: 14.9465
# Epoch [0/5], Step [830/3236], Loss: 2.6489, Perplexity: 14.1378
# Epoch [0/5], Step [840/3236], Loss: 2.5797, Perplexity: 13.1932
# Epoch [0/5], Step [850/3236], Loss: 2.6951, Perplexity: 14.8065
# Epoch [0/5], Step [860/3236], Loss: 2.7454, Perplexity: 15.5707
# Epoch [0/5], Step [870/3236], Loss: 2.5617, Perplexity: 12.9576
# Epoch [0/5], Step [880/3236], Loss: 2.5567, Perplexity: 12.8938
# Epoch [0/5], Step [890/3236], Loss: 2.6301, Perplexity: 13.8749
# Epoch [0/5], Step [900/3236], Loss: 2.6564, Perplexity: 14.2453
# Epoch [0/5], Step [910/3236], Loss: 2.6679, Perplexity: 14.4102
# Epoch [0/5], Step [920/3236], Loss: 2.5814, Perplexity: 13.2157
# Epoch [0/5], Step [930/3236], Loss: 2.6314, Perplexity: 13.8932
# Epoch [0/5], Step [940/3236], Loss: 2.6277, Perplexity: 13.8413
# Epoch [0/5], Step [950/3236], Loss: 2.6827, Perplexity: 14.6239
# Epoch [0/5], Step [960/3236], Loss: 2.5926, Perplexity: 13.3642
# Epoch [0/5], Step [970/3236], Loss: 2.6044, Perplexity: 13.5238
# Epoch [0/5], Step [980/3236], Loss: 2.4835, Perplexity: 11.9827
# Epoch [0/5], Step [990/3236], Loss: 2.7086, Perplexity: 15.0080
# Epoch [0/5], Step [1000/3236], Loss: 2.4312, Perplexity: 11.3728
# Epoch [0/5], Step [1010/3236], Loss: 2.4872, Perplexity: 12.0272
# Epoch [0/5], Step [1020/3236], Loss: 2.6118, Perplexity: 13.6235
# Epoch [0/5], Step [1030/3236], Loss: 2.5793, Perplexity: 13.1873
# Epoch [0/5], Step [1040/3236], Loss: 2.3795, Perplexity: 10.7993
# Epoch [0/5], Step [1050/3236], Loss: 2.5169, Perplexity: 12.3901
# Epoch [0/5], Step [1060/3236], Loss: 2.5799, Perplexity: 13.1956
# Epoch [0/5], Step [1070/3236], Loss: 2.5745, Perplexity: 13.1252
# Epoch [0/5], Step [1080/3236], Loss: 2.4304, Perplexity: 11.3630
# Epoch [0/5], Step [1090/3236], Loss: 2.6443, Perplexity: 14.0736
# Epoch [0/5], Step [1100/3236], Loss: 2.4700, Perplexity: 11.8221
# Epoch [0/5], Step [1110/3236], Loss: 2.5459, Perplexity: 12.7544
# Epoch [0/5], Step [1120/3236], Loss: 2.5792, Perplexity: 13.1866
# Epoch [0/5], Step [1130/3236], Loss: 2.5275, Perplexity: 12.5219
# Epoch [0/5], Step [1140/3236], Loss: 2.6642, Perplexity: 14.3561
# Epoch [0/5], Step [1150/3236], Loss: 2.5211, Perplexity: 12.4423
# Epoch [0/5], Step [1160/3236], Loss: 2.4611, Perplexity: 11.7173
# Epoch [0/5], Step [1170/3236], Loss: 2.4728, Perplexity: 11.8551
# Epoch [0/5], Step [1180/3236], Loss: 2.5267, Perplexity: 12.5122
# Epoch [0/5], Step [1190/3236], Loss: 2.5548, Perplexity: 12.8683
# Epoch [0/5], Step [1200/3236], Loss: 2.6388, Perplexity: 13.9969
# Epoch [0/5], Step [1210/3236], Loss: 2.5911, Perplexity: 13.3443
# Epoch [0/5], Step [1220/3236], Loss: 2.5479, Perplexity: 12.7804
# Epoch [0/5], Step [1230/3236], Loss: 2.4409, Perplexity: 11.4838
# Epoch [0/5], Step [1240/3236], Loss: 2.5567, Perplexity: 12.8935
# Epoch [0/5], Step [1250/3236], Loss: 2.4352, Perplexity: 11.4181
# Epoch [0/5], Step [1260/3236], Loss: 2.5571, Perplexity: 12.8978
# Epoch [0/5], Step [1270/3236], Loss: 2.6194, Perplexity: 13.7275
# Epoch [0/5], Step [1280/3236], Loss: 2.4616, Perplexity: 11.7233
# Epoch [0/5], Step [1290/3236], Loss: 2.4399, Perplexity: 11.4719
# Epoch [0/5], Step [1300/3236], Loss: 2.4799, Perplexity: 11.9403
# Epoch [0/5], Step [1310/3236], Loss: 2.6313, Perplexity: 13.8913
# Epoch [0/5], Step [1320/3236], Loss: 2.4524, Perplexity: 11.6156
# Epoch [0/5], Step [1330/3236], Loss: 2.4148, Perplexity: 11.1878
# Epoch [0/5], Step [1340/3236], Loss: 2.3466, Perplexity: 10.4498
# Epoch [0/5], Step [1350/3236], Loss: 2.4222, Perplexity: 11.2711
# Epoch [0/5], Step [1360/3236], Loss: 2.5537, Perplexity: 12.8547
# Epoch [0/5], Step [1370/3236], Loss: 2.5110, Perplexity: 12.3171
# Epoch [0/5], Step [1380/3236], Loss: 2.4146, Perplexity: 11.1853
# Epoch [0/5], Step [1390/3236], Loss: 2.4343, Perplexity: 11.4084
# Epoch [0/5], Step [1400/3236], Loss: 2.4363, Perplexity: 11.4303
# Epoch [0/5], Step [1410/3236], Loss: 2.4764, Perplexity: 11.8981
# Epoch [0/5], Step [1420/3236], Loss: 2.4521, Perplexity: 11.6126
# Epoch [0/5], Step [1430/3236], Loss: 2.5145, Perplexity: 12.3602
# Epoch [0/5], Step [1440/3236], Loss: 2.4869, Perplexity: 12.0245
# Epoch [0/5], Step [1450/3236], Loss: 2.3185, Perplexity: 10.1606
# Epoch [0/5], Step [1460/3236], Loss: 2.4925, Perplexity: 12.0920
# Epoch [0/5], Step [1470/3236], Loss: 2.4776, Perplexity: 11.9125
# Epoch [0/5], Step [1480/3236], Loss: 2.5219, Perplexity: 12.4525
# Epoch [0/5], Step [1490/3236], Loss: 2.3943, Perplexity: 10.9605
# Epoch [0/5], Step [1500/3236], Loss: 2.3775, Perplexity: 10.7781
# Epoch [0/5], Step [1510/3236], Loss: 2.4694, Perplexity: 11.8153
# Epoch [0/5], Step [1520/3236], Loss: 2.5012, Perplexity: 12.1976
# Epoch [0/5], Step [1530/3236], Loss: 2.3944, Perplexity: 10.9621
# Epoch [0/5], Step [1540/3236], Loss: 2.3369, Perplexity: 10.3489
# Epoch [0/5], Step [1550/3236], Loss: 2.3581, Perplexity: 10.5706
# Epoch [0/5], Step [1560/3236], Loss: 2.5004, Perplexity: 12.1869
# Epoch [0/5], Step [1570/3236], Loss: 2.5607, Perplexity: 12.9453
# Epoch [0/5], Step [1580/3236], Loss: 2.3619, Perplexity: 10.6112
# Epoch [0/5], Step [1590/3236], Loss: 2.5353, Perplexity: 12.6201
# Epoch [0/5], Step [1600/3236], Loss: 2.5016, Perplexity: 12.2015
# Epoch [0/5], Step [1610/3236], Loss: 2.5336, Perplexity: 12.5990
# Epoch [0/5], Step [1620/3236], Loss: 2.3131, Perplexity: 10.1053
# Epoch [0/5], Step [1630/3236], Loss: 2.3942, Perplexity: 10.9594
# Epoch [0/5], Step [1640/3236], Loss: 2.4069, Perplexity: 11.0993
# Epoch [0/5], Step [1650/3236], Loss: 2.3204, Perplexity: 10.1796
# Epoch [0/5], Step [1660/3236], Loss: 2.4788, Perplexity: 11.9265
# Epoch [0/5], Step [1670/3236], Loss: 2.4034, Perplexity: 11.0609
# Epoch [0/5], Step [1680/3236], Loss: 2.3646, Perplexity: 10.6396
# Epoch [0/5], Step [1690/3236], Loss: 2.4755, Perplexity: 11.8873
# Epoch [0/5], Step [1700/3236], Loss: 2.5007, Perplexity: 12.1906
# Epoch [0/5], Step [1710/3236], Loss: 2.3997, Perplexity: 11.0201
# Epoch [0/5], Step [1720/3236], Loss: 2.2973, Perplexity: 9.9476
# Epoch [0/5], Step [1730/3236], Loss: 2.4016, Perplexity: 11.0404
# Epoch [0/5], Step [1740/3236], Loss: 2.4621, Perplexity: 11.7291
# Epoch [0/5], Step [1750/3236], Loss: 2.3999, Perplexity: 11.0218
# Epoch [0/5], Step [1760/3236], Loss: 2.4634, Perplexity: 11.7442
# Epoch [0/5], Step [1770/3236], Loss: 2.1848, Perplexity: 8.8891
# Epoch [0/5], Step [1780/3236], Loss: 2.2126, Perplexity: 9.1390
# Epoch [0/5], Step [1790/3236], Loss: 2.2902, Perplexity: 9.8768
# Epoch [0/5], Step [1800/3236], Loss: 2.3915, Perplexity: 10.9300
# Epoch [0/5], Step [1810/3236], Loss: 2.3876, Perplexity: 10.8878
# Epoch [0/5], Step [1820/3236], Loss: 2.3776, Perplexity: 10.7790
# Epoch [0/5], Step [1830/3236], Loss: 2.2731, Perplexity: 9.7097
# Epoch [0/5], Step [1840/3236], Loss: 2.3103, Perplexity: 10.0778
# Epoch [0/5], Step [1850/3236], Loss: 2.3647, Perplexity: 10.6411
# Epoch [0/5], Step [1860/3236], Loss: 2.4679, Perplexity: 11.7977
# Epoch [0/5], Step [1870/3236], Loss: 2.5036, Perplexity: 12.2270
# Epoch [0/5], Step [1880/3236], Loss: 2.3774, Perplexity: 10.7765
# Epoch [0/5], Step [1890/3236], Loss: 2.3782, Perplexity: 10.7851
# Epoch [0/5], Step [1900/3236], Loss: 2.3599, Perplexity: 10.5901
# Epoch [0/5], Step [1910/3236], Loss: 2.3516, Perplexity: 10.5021
# Epoch [0/5], Step [1920/3236], Loss: 2.3334, Perplexity: 10.3126
# Epoch [0/5], Step [1930/3236], Loss: 2.3206, Perplexity: 10.1816
# Epoch [0/5], Step [1940/3236], Loss: 2.4577, Perplexity: 11.6778
# Epoch [0/5], Step [1950/3236], Loss: 2.3490, Perplexity: 10.4752
# Epoch [0/5], Step [1960/3236], Loss: 2.3547, Perplexity: 10.5351
# Epoch [0/5], Step [1970/3236], Loss: 2.2187, Perplexity: 9.1952
# Epoch [0/5], Step [1980/3236], Loss: 2.2523, Perplexity: 9.5093
# Epoch [0/5], Step [1990/3236], Loss: 2.3001, Perplexity: 9.9756
# Epoch [0/5], Step [2000/3236], Loss: 2.2598, Perplexity: 9.5815
# Epoch [0/5], Step [2010/3236], Loss: 2.4243, Perplexity: 11.2945
# Epoch [0/5], Step [2020/3236], Loss: 2.2756, Perplexity: 9.7342
# Epoch [0/5], Step [2030/3236], Loss: 2.3773, Perplexity: 10.7761
# Epoch [0/5], Step [2040/3236], Loss: 2.2868, Perplexity: 9.8436
# Epoch [0/5], Step [2050/3236], Loss: 2.3287, Perplexity: 10.2650
# Epoch [0/5], Step [2060/3236], Loss: 2.2806, Perplexity: 9.7823
# Epoch [0/5], Step [2070/3236], Loss: 2.3826, Perplexity: 10.8328
# Epoch [0/5], Step [2080/3236], Loss: 2.3283, Perplexity: 10.2601
# Epoch [0/5], Step [2090/3236], Loss: 2.2340, Perplexity: 9.3375
# Epoch [0/5], Step [2100/3236], Loss: 2.3934, Perplexity: 10.9503
# Epoch [0/5], Step [2110/3236], Loss: 2.3393, Perplexity: 10.3737
# Epoch [0/5], Step [2120/3236], Loss: 2.3302, Perplexity: 10.2797
# Epoch [0/5], Step [2130/3236], Loss: 2.3301, Perplexity: 10.2788
# Epoch [0/5], Step [2140/3236], Loss: 2.4029, Perplexity: 11.0553
# Epoch [0/5], Step [2150/3236], Loss: 2.3918, Perplexity: 10.9328
# Epoch [0/5], Step [2160/3236], Loss: 2.4236, Perplexity: 11.2859
# Epoch [0/5], Step [2170/3236], Loss: 2.3493, Perplexity: 10.4785
# Epoch [0/5], Step [2180/3236], Loss: 2.2993, Perplexity: 9.9672
# Epoch [0/5], Step [2190/3236], Loss: 2.3822, Perplexity: 10.8289
# Epoch [0/5], Step [2200/3236], Loss: 2.3422, Perplexity: 10.4039
# Epoch [0/5], Step [2210/3236], Loss: 2.1341, Perplexity: 8.4492
# Epoch [0/5], Step [2220/3236], Loss: 2.2012, Perplexity: 9.0357
# Epoch [0/5], Step [2230/3236], Loss: 2.3720, Perplexity: 10.7184
# Epoch [0/5], Step [2240/3236], Loss: 2.4235, Perplexity: 11.2852
# Epoch [0/5], Step [2250/3236], Loss: 2.2421, Perplexity: 9.4127
# Epoch [0/5], Step [2260/3236], Loss: 2.3175, Perplexity: 10.1501
# Epoch [0/5], Step [2270/3236], Loss: 2.2241, Perplexity: 9.2449
# Epoch [0/5], Step [2280/3236], Loss: 2.1209, Perplexity: 8.3390
# Epoch [0/5], Step [2290/3236], Loss: 2.5070, Perplexity: 12.2677
# Epoch [0/5], Step [2300/3236], Loss: 2.3122, Perplexity: 10.0969
# Epoch [0/5], Step [2310/3236], Loss: 2.4045, Perplexity: 11.0729
# Epoch [0/5], Step [2320/3236], Loss: 2.2392, Perplexity: 9.3862
# Epoch [0/5], Step [2330/3236], Loss: 2.4578, Perplexity: 11.6794
# Epoch [0/5], Step [2340/3236], Loss: 2.5111, Perplexity: 12.3182
# Epoch [0/5], Step [2350/3236], Loss: 2.3250, Perplexity: 10.2268
# Epoch [0/5], Step [2360/3236], Loss: 2.2679, Perplexity: 9.6592
# Epoch [0/5], Step [2370/3236], Loss: 2.3366, Perplexity: 10.3459
# Epoch [0/5], Step [2380/3236], Loss: 2.3183, Perplexity: 10.1584
# Epoch [0/5], Step [2390/3236], Loss: 2.3604, Perplexity: 10.5951
# Epoch [0/5], Step [2400/3236], Loss: 2.2773, Perplexity: 9.7499
# Epoch [0/5], Step [2410/3236], Loss: 2.3304, Perplexity: 10.2819
# Epoch [0/5], Step [2420/3236], Loss: 2.0781, Perplexity: 7.9893
# Epoch [0/5], Step [2430/3236], Loss: 2.3640, Perplexity: 10.6330
# Epoch [0/5], Step [2440/3236], Loss: 2.2258, Perplexity: 9.2612
# Epoch [0/5], Step [2450/3236], Loss: 2.2681, Perplexity: 9.6610
# Epoch [0/5], Step [2460/3236], Loss: 2.1815, Perplexity: 8.8600
# Epoch [0/5], Step [2470/3236], Loss: 2.1784, Perplexity: 8.8323
# Epoch [0/5], Step [2480/3236], Loss: 2.3844, Perplexity: 10.8522
# Epoch [0/5], Step [2490/3236], Loss: 2.1030, Perplexity: 8.1909
# Epoch [0/5], Step [2500/3236], Loss: 2.3397, Perplexity: 10.3784
# Epoch [0/5], Step [2510/3236], Loss: 2.4146, Perplexity: 11.1854
# Epoch [0/5], Step [2520/3236], Loss: 2.1715, Perplexity: 8.7714
# Epoch [0/5], Step [2530/3236], Loss: 2.3598, Perplexity: 10.5887
# Epoch [0/5], Step [2540/3236], Loss: 2.3004, Perplexity: 9.9782
# Epoch [0/5], Step [2550/3236], Loss: 2.4131, Perplexity: 11.1688
# Epoch [0/5], Step [2560/3236], Loss: 2.2636, Perplexity: 9.6179
# Epoch [0/5], Step [2570/3236], Loss: 2.2583, Perplexity: 9.5664
# Epoch [0/5], Step [2580/3236], Loss: 2.4476, Perplexity: 11.5607
# Epoch [0/5], Step [2590/3236], Loss: 2.4155, Perplexity: 11.1950
# Epoch [0/5], Step [2600/3236], Loss: 2.1588, Perplexity: 8.6608
# Epoch [0/5], Step [2610/3236], Loss: 2.2382, Perplexity: 9.3768
# Epoch [0/5], Step [2620/3236], Loss: 2.3404, Perplexity: 10.3854
# Epoch [0/5], Step [2630/3236], Loss: 2.2611, Perplexity: 9.5932
# Epoch [0/5], Step [2640/3236], Loss: 2.1070, Perplexity: 8.2233
# Epoch [0/5], Step [2650/3236], Loss: 2.2352, Perplexity: 9.3488
# Epoch [0/5], Step [2660/3236], Loss: 2.2938, Perplexity: 9.9126
# Epoch [0/5], Step [2670/3236], Loss: 2.2119, Perplexity: 9.1329
# Epoch [0/5], Step [2680/3236], Loss: 2.2108, Perplexity: 9.1228
# Epoch [0/5], Step [2690/3236], Loss: 2.3748, Perplexity: 10.7494
# Epoch [0/5], Step [2700/3236], Loss: 2.1863, Perplexity: 8.9019
# Epoch [0/5], Step [2710/3236], Loss: 2.2999, Perplexity: 9.9736
# Epoch [0/5], Step [2720/3236], Loss: 2.3059, Perplexity: 10.0333
# Epoch [0/5], Step [2730/3236], Loss: 2.2134, Perplexity: 9.1468
# Epoch [0/5], Step [2740/3236], Loss: 2.3008, Perplexity: 9.9826
# Epoch [0/5], Step [2750/3236], Loss: 2.2291, Perplexity: 9.2910
# Epoch [0/5], Step [2760/3236], Loss: 2.4117, Perplexity: 11.1524
# Epoch [0/5], Step [2770/3236], Loss: 2.1709, Perplexity: 8.7661
# Epoch [0/5], Step [2780/3236], Loss: 2.2515, Perplexity: 9.5018
# Epoch [0/5], Step [2790/3236], Loss: 2.1641, Perplexity: 8.7066
# Epoch [0/5], Step [2800/3236], Loss: 2.2813, Perplexity: 9.7895
# Epoch [0/5], Step [2810/3236], Loss: 2.1244, Perplexity: 8.3675
# Epoch [0/5], Step [2820/3236], Loss: 2.1500, Perplexity: 8.5848
# Epoch [0/5], Step [2830/3236], Loss: 2.1555, Perplexity: 8.6322
# Epoch [0/5], Step [2840/3236], Loss: 2.1564, Perplexity: 8.6397
# Epoch [0/5], Step [2850/3236], Loss: 2.3469, Perplexity: 10.4532
# Epoch [0/5], Step [2860/3236], Loss: 2.3634, Perplexity: 10.6274
# Epoch [0/5], Step [2870/3236], Loss: 2.1973, Perplexity: 9.0008
# Epoch [0/5], Step [2880/3236], Loss: 2.2071, Perplexity: 9.0897
# Epoch [0/5], Step [2890/3236], Loss: 2.2283, Perplexity: 9.2837
# Epoch [0/5], Step [2900/3236], Loss: 2.1234, Perplexity: 8.3598
# Epoch [0/5], Step [2910/3236], Loss: 2.3117, Perplexity: 10.0914
# Epoch [0/5], Step [2920/3236], Loss: 2.2315, Perplexity: 9.3140
# Epoch [0/5], Step [2930/3236], Loss: 2.1863, Perplexity: 8.9022
# Epoch [0/5], Step [2940/3236], Loss: 2.3157, Perplexity: 10.1318
# Epoch [0/5], Step [2950/3236], Loss: 2.2471, Perplexity: 9.4603
# Epoch [0/5], Step [2960/3236], Loss: 2.2404, Perplexity: 9.3969
# Epoch [0/5], Step [2970/3236], Loss: 2.3033, Perplexity: 10.0069
# Epoch [0/5], Step [2980/3236], Loss: 2.1861, Perplexity: 8.9007
# Epoch [0/5], Step [2990/3236], Loss: 2.2701, Perplexity: 9.6808
# Epoch [0/5], Step [3000/3236], Loss: 2.3634, Perplexity: 10.6272
# Epoch [0/5], Step [3010/3236], Loss: 2.3391, Perplexity: 10.3716
# Epoch [0/5], Step [3020/3236], Loss: 2.2685, Perplexity: 9.6650
# Epoch [0/5], Step [3030/3236], Loss: 2.2530, Perplexity: 9.5162
# Epoch [0/5], Step [3040/3236], Loss: 2.2590, Perplexity: 9.5739
# Epoch [0/5], Step [3050/3236], Loss: 2.3860, Perplexity: 10.8704
# Epoch [0/5], Step [3060/3236], Loss: 2.4536, Perplexity: 11.6303
# Epoch [0/5], Step [3070/3236], Loss: 2.1056, Perplexity: 8.2118
# Epoch [0/5], Step [3080/3236], Loss: 2.2941, Perplexity: 9.9157
# Epoch [0/5], Step [3090/3236], Loss: 2.2507, Perplexity: 9.4942
# Epoch [0/5], Step [3100/3236], Loss: 2.2497, Perplexity: 9.4847
# Epoch [0/5], Step [3110/3236], Loss: 2.2307, Perplexity: 9.3066
# Epoch [0/5], Step [3120/3236], Loss: 2.2410, Perplexity: 9.4028
# Epoch [0/5], Step [3130/3236], Loss: 2.1771, Perplexity: 8.8204
# Epoch [0/5], Step [3140/3236], Loss: 2.2303, Perplexity: 9.3029
# Epoch [0/5], Step [3150/3236], Loss: 2.2333, Perplexity: 9.3302
# Epoch [0/5], Step [3160/3236], Loss: 2.3016, Perplexity: 9.9905
# Epoch [0/5], Step [3170/3236], Loss: 2.2745, Perplexity: 9.7231
# Epoch [0/5], Step [3180/3236], Loss: 2.2752, Perplexity: 9.7298
# Epoch [0/5], Step [3190/3236], Loss: 2.4677, Perplexity: 11.7955
# Epoch [0/5], Step [3200/3236], Loss: 2.3148, Perplexity: 10.1234
# Epoch [0/5], Step [3210/3236], Loss: 2.3052, Perplexity: 10.0260
# Epoch [0/5], Step [3220/3236], Loss: 2.3335, Perplexity: 10.3142
# Epoch [0/5], Step [3230/3236], Loss: 2.2818, Perplexity: 9.7941
# Epoch [1/5], Step [0/3236], Loss: 2.1996, Perplexity: 9.0210
# Epoch [1/5], Step [10/3236], Loss: 2.1074, Perplexity: 8.2270
# Epoch [1/5], Step [20/3236], Loss: 2.2145, Perplexity: 9.1572
# Epoch [1/5], Step [30/3236], Loss: 2.1920, Perplexity: 8.9531
# Epoch [1/5], Step [40/3236], Loss: 2.1492, Perplexity: 8.5781
# Epoch [1/5], Step [50/3236], Loss: 2.0698, Perplexity: 7.9232
# Epoch [1/5], Step [60/3236], Loss: 2.0939, Perplexity: 8.1165
# Epoch [1/5], Step [70/3236], Loss: 2.3299, Perplexity: 10.2774
# Epoch [1/5], Step [80/3236], Loss: 2.2526, Perplexity: 9.5123
# Epoch [1/5], Step [90/3236], Loss: 2.2492, Perplexity: 9.4800
# Epoch [1/5], Step [100/3236], Loss: 2.2392, Perplexity: 9.3861
# Epoch [1/5], Step [110/3236], Loss: 2.2967, Perplexity: 9.9415
# Epoch [1/5], Step [120/3236], Loss: 2.2688, Perplexity: 9.6676
# Epoch [1/5], Step [130/3236], Loss: 2.2327, Perplexity: 9.3249
# Epoch [1/5], Step [140/3236], Loss: 2.2048, Perplexity: 9.0687
# Epoch [1/5], Step [150/3236], Loss: 2.1540, Perplexity: 8.6189
# Epoch [1/5], Step [160/3236], Loss: 2.0737, Perplexity: 7.9539
# Epoch [1/5], Step [170/3236], Loss: 2.0570, Perplexity: 7.8225
# Epoch [1/5], Step [180/3236], Loss: 2.1963, Perplexity: 8.9921
# Epoch [1/5], Step [190/3236], Loss: 2.2247, Perplexity: 9.2507
# Epoch [1/5], Step [200/3236], Loss: 2.0603, Perplexity: 7.8480
# Epoch [1/5], Step [210/3236], Loss: 2.2609, Perplexity: 9.5920
# Epoch [1/5], Step [220/3236], Loss: 2.1744, Perplexity: 8.7965
# Epoch [1/5], Step [230/3236], Loss: 2.2826, Perplexity: 9.8017
# Epoch [1/5], Step [240/3236], Loss: 2.0618, Perplexity: 7.8598
# Epoch [1/5], Step [250/3236], Loss: 2.1728, Perplexity: 8.7826
# Epoch [1/5], Step [260/3236], Loss: 2.1881, Perplexity: 8.9183
# Epoch [1/5], Step [270/3236], Loss: 2.2370, Perplexity: 9.3647
# Epoch [1/5], Step [280/3236], Loss: 2.2361, Perplexity: 9.3564
# Epoch [1/5], Step [290/3236], Loss: 2.1349, Perplexity: 8.4559
# Epoch [1/5], Step [300/3236], Loss: 2.1589, Perplexity: 8.6619
# Epoch [1/5], Step [310/3236], Loss: 2.1894, Perplexity: 8.9302
# Epoch [1/5], Step [320/3236], Loss: 2.1500, Perplexity: 8.5845
# Epoch [1/5], Step [330/3236], Loss: 2.3124, Perplexity: 10.0988
# Epoch [1/5], Step [340/3236], Loss: 2.2197, Perplexity: 9.2049
# Epoch [1/5], Step [350/3236], Loss: 2.2742, Perplexity: 9.7200
# Epoch [1/5], Step [360/3236], Loss: 2.3623, Perplexity: 10.6153
# Epoch [1/5], Step [370/3236], Loss: 2.0843, Perplexity: 8.0392
# Epoch [1/5], Step [380/3236], Loss: 2.1390, Perplexity: 8.4909
# Epoch [1/5], Step [390/3236], Loss: 2.0811, Perplexity: 8.0130
# Epoch [1/5], Step [400/3236], Loss: 2.1378, Perplexity: 8.4805
# Epoch [1/5], Step [410/3236], Loss: 2.1252, Perplexity: 8.3745
# Epoch [1/5], Step [420/3236], Loss: 2.1654, Perplexity: 8.7179
# Epoch [1/5], Step [430/3236], Loss: 2.0958, Perplexity: 8.1320
# Epoch [1/5], Step [440/3236], Loss: 2.1359, Perplexity: 8.4647
# Epoch [1/5], Step [450/3236], Loss: 2.1641, Perplexity: 8.7064
# Epoch [1/5], Step [460/3236], Loss: 2.1863, Perplexity: 8.9020
# Epoch [1/5], Step [470/3236], Loss: 2.1489, Perplexity: 8.5753
# Epoch [1/5], Step [480/3236], Loss: 2.1201, Perplexity: 8.3319
# Epoch [1/5], Step [490/3236], Loss: 2.1917, Perplexity: 8.9504
# Epoch [1/5], Step [500/3236], Loss: 2.1332, Perplexity: 8.4421
# Epoch [1/5], Step [510/3236], Loss: 2.1928, Perplexity: 8.9606
# Epoch [1/5], Step [520/3236], Loss: 2.1734, Perplexity: 8.7883
# Epoch [1/5], Step [530/3236], Loss: 2.1686, Perplexity: 8.7458
# Epoch [1/5], Step [540/3236], Loss: 2.2951, Perplexity: 9.9250
# Epoch [1/5], Step [550/3236], Loss: 2.1525, Perplexity: 8.6065
# Epoch [1/5], Step [560/3236], Loss: 2.2367, Perplexity: 9.3625
# Epoch [1/5], Step [570/3236], Loss: 2.3512, Perplexity: 10.4979
# Epoch [1/5], Step [580/3236], Loss: 2.1579, Perplexity: 8.6530
# Epoch [1/5], Step [590/3236], Loss: 2.1565, Perplexity: 8.6408
# Epoch [1/5], Step [600/3236], Loss: 2.2320, Perplexity: 9.3183
# Epoch [1/5], Step [610/3236], Loss: 2.0181, Perplexity: 7.5240
# Epoch [1/5], Step [620/3236], Loss: 2.0345, Perplexity: 7.6484
# Epoch [1/5], Step [630/3236], Loss: 2.0338, Perplexity: 7.6431
# Epoch [1/5], Step [640/3236], Loss: 2.2377, Perplexity: 9.3718
# Epoch [1/5], Step [650/3236], Loss: 2.0936, Perplexity: 8.1144
# Epoch [1/5], Step [660/3236], Loss: 2.1789, Perplexity: 8.8370
# Epoch [1/5], Step [670/3236], Loss: 2.0651, Perplexity: 7.8861
# Epoch [1/5], Step [680/3236], Loss: 2.1907, Perplexity: 8.9417
# Epoch [1/5], Step [690/3236], Loss: 2.1861, Perplexity: 8.9008
# Epoch [1/5], Step [700/3236], Loss: 2.1688, Perplexity: 8.7474
# Epoch [1/5], Step [710/3236], Loss: 2.1290, Perplexity: 8.4068
# Epoch [1/5], Step [720/3236], Loss: 2.1279, Perplexity: 8.3972
# Epoch [1/5], Step [730/3236], Loss: 2.2235, Perplexity: 9.2400
# Epoch [1/5], Step [740/3236], Loss: 2.1788, Perplexity: 8.8358
# Epoch [1/5], Step [750/3236], Loss: 2.0881, Perplexity: 8.0692
# Epoch [1/5], Step [760/3236], Loss: 2.3273, Perplexity: 10.2502
# Epoch [1/5], Step [770/3236], Loss: 2.0713, Perplexity: 7.9351
# Epoch [1/5], Step [780/3236], Loss: 2.1135, Perplexity: 8.2769
# Epoch [1/5], Step [790/3236], Loss: 2.1316, Perplexity: 8.4284
# Epoch [1/5], Step [800/3236], Loss: 2.1812, Perplexity: 8.8566
# Epoch [1/5], Step [810/3236], Loss: 2.1596, Perplexity: 8.6679
# Epoch [1/5], Step [820/3236], Loss: 2.2951, Perplexity: 9.9252
# Epoch [1/5], Step [830/3236], Loss: 2.0974, Perplexity: 8.1450
# Epoch [1/5], Step [840/3236], Loss: 2.1175, Perplexity: 8.3104
# Epoch [1/5], Step [850/3236], Loss: 2.0146, Perplexity: 7.4976
# Epoch [1/5], Step [860/3236], Loss: 2.0591, Perplexity: 7.8386
# Epoch [1/5], Step [870/3236], Loss: 2.1144, Perplexity: 8.2847
# Epoch [1/5], Step [880/3236], Loss: 2.1964, Perplexity: 8.9925
# Epoch [1/5], Step [890/3236], Loss: 2.2055, Perplexity: 9.0747
# Epoch [1/5], Step [900/3236], Loss: 2.1503, Perplexity: 8.5872
# Epoch [1/5], Step [910/3236], Loss: 2.0651, Perplexity: 7.8861
# Epoch [1/5], Step [920/3236], Loss: 2.3305, Perplexity: 10.2832
# Epoch [1/5], Step [930/3236], Loss: 2.1777, Perplexity: 8.8258
# Epoch [1/5], Step [940/3236], Loss: 2.1521, Perplexity: 8.6025
# Epoch [1/5], Step [950/3236], Loss: 2.1335, Perplexity: 8.4446
# Epoch [1/5], Step [960/3236], Loss: 2.1047, Perplexity: 8.2046
# Epoch [1/5], Step [970/3236], Loss: 2.0724, Perplexity: 7.9441
# Epoch [1/5], Step [980/3236], Loss: 2.0801, Perplexity: 8.0051
# Epoch [1/5], Step [990/3236], Loss: 2.2099, Perplexity: 9.1151
# Epoch [1/5], Step [1000/3236], Loss: 2.1933, Perplexity: 8.9646
# Epoch [1/5], Step [1010/3236], Loss: 2.2568, Perplexity: 9.5524
# Epoch [1/5], Step [1020/3236], Loss: 2.2200, Perplexity: 9.2070
# Epoch [1/5], Step [1030/3236], Loss: 2.1387, Perplexity: 8.4883
# Epoch [1/5], Step [1040/3236], Loss: 2.1142, Perplexity: 8.2832
# Epoch [1/5], Step [1050/3236], Loss: 2.1554, Perplexity: 8.6314
# Epoch [1/5], Step [1060/3236], Loss: 2.0584, Perplexity: 7.8333
# Epoch [1/5], Step [1070/3236], Loss: 2.0886, Perplexity: 8.0737
# Epoch [1/5], Step [1080/3236], Loss: 2.1214, Perplexity: 8.3426
# Epoch [1/5], Step [1090/3236], Loss: 2.1677, Perplexity: 8.7385
# Epoch [1/5], Step [1100/3236], Loss: 2.0711, Perplexity: 7.9334
# Epoch [1/5], Step [1110/3236], Loss: 2.1430, Perplexity: 8.5253
# Epoch [1/5], Step [1120/3236], Loss: 2.0835, Perplexity: 8.0329
# Epoch [1/5], Step [1130/3236], Loss: 2.1200, Perplexity: 8.3314
# Epoch [1/5], Step [1140/3236], Loss: 1.9529, Perplexity: 7.0489
# Epoch [1/5], Step [1150/3236], Loss: 2.1736, Perplexity: 8.7899
# Epoch [1/5], Step [1160/3236], Loss: 2.1457, Perplexity: 8.5481
# Epoch [1/5], Step [1170/3236], Loss: 2.0287, Perplexity: 7.6044
# Epoch [1/5], Step [1180/3236], Loss: 2.2402, Perplexity: 9.3957
# Epoch [1/5], Step [1190/3236], Loss: 2.1916, Perplexity: 8.9491
# Epoch [1/5], Step [1200/3236], Loss: 2.1480, Perplexity: 8.5675
# Epoch [1/5], Step [1210/3236], Loss: 2.0635, Perplexity: 7.8735
# Epoch [1/5], Step [1220/3236], Loss: 2.1957, Perplexity: 8.9866
# Epoch [1/5], Step [1230/3236], Loss: 2.1748, Perplexity: 8.8002
# Epoch [1/5], Step [1240/3236], Loss: 2.0580, Perplexity: 7.8300
# Epoch [1/5], Step [1250/3236], Loss: 2.0639, Perplexity: 7.8769
# Epoch [1/5], Step [1260/3236], Loss: 2.1114, Perplexity: 8.2598
# Epoch [1/5], Step [1270/3236], Loss: 2.2541, Perplexity: 9.5265
# Epoch [1/5], Step [1280/3236], Loss: 2.0723, Perplexity: 7.9433
# Epoch [1/5], Step [1290/3236], Loss: 2.2763, Perplexity: 9.7407
# Epoch [1/5], Step [1300/3236], Loss: 2.1609, Perplexity: 8.6786
# Epoch [1/5], Step [1310/3236], Loss: 2.1495, Perplexity: 8.5809
# Epoch [1/5], Step [1320/3236], Loss: 2.2142, Perplexity: 9.1540
# Epoch [1/5], Step [1330/3236], Loss: 2.1605, Perplexity: 8.6751
# Epoch [1/5], Step [1340/3236], Loss: 2.0286, Perplexity: 7.6031
# Epoch [1/5], Step [1350/3236], Loss: 2.0902, Perplexity: 8.0864
# Epoch [1/5], Step [1360/3236], Loss: 2.0568, Perplexity: 7.8205
# Epoch [1/5], Step [1370/3236], Loss: 2.0875, Perplexity: 8.0651
# Epoch [1/5], Step [1380/3236], Loss: 1.9873, Perplexity: 7.2957
# Epoch [1/5], Step [1390/3236], Loss: 2.0914, Perplexity: 8.0964
# Epoch [1/5], Step [1400/3236], Loss: 2.0724, Perplexity: 7.9440
# Epoch [1/5], Step [1410/3236], Loss: 2.1237, Perplexity: 8.3620
# Epoch [1/5], Step [1420/3236], Loss: 2.0451, Perplexity: 7.7297
# Epoch [1/5], Step [1430/3236], Loss: 2.2044, Perplexity: 9.0649
# Epoch [1/5], Step [1440/3236], Loss: 2.1126, Perplexity: 8.2701
# Epoch [1/5], Step [1450/3236], Loss: 1.9187, Perplexity: 6.8121
# Epoch [1/5], Step [1460/3236], Loss: 2.1116, Perplexity: 8.2615
# Epoch [1/5], Step [1470/3236], Loss: 2.2146, Perplexity: 9.1579
# Epoch [1/5], Step [1480/3236], Loss: 2.1079, Perplexity: 8.2312
# Epoch [1/5], Step [1490/3236], Loss: 2.2063, Perplexity: 9.0818
# Epoch [1/5], Step [1500/3236], Loss: 2.1700, Perplexity: 8.7583
# Epoch [1/5], Step [1510/3236], Loss: 2.1090, Perplexity: 8.2397
# Epoch [1/5], Step [1520/3236], Loss: 2.1252, Perplexity: 8.3744
# Epoch [1/5], Step [1530/3236], Loss: 2.0858, Perplexity: 8.0512
# Epoch [1/5], Step [1540/3236], Loss: 2.1659, Perplexity: 8.7229
# Epoch [1/5], Step [1550/3236], Loss: 2.1950, Perplexity: 8.9796
# Epoch [1/5], Step [1560/3236], Loss: 2.2360, Perplexity: 9.3555
# Epoch [1/5], Step [1570/3236], Loss: 2.0778, Perplexity: 7.9866
# Epoch [1/5], Step [1580/3236], Loss: 2.1116, Perplexity: 8.2613
# Epoch [1/5], Step [1590/3236], Loss: 2.0595, Perplexity: 7.8417
# Epoch [1/5], Step [1600/3236], Loss: 2.1536, Perplexity: 8.6162
# Epoch [1/5], Step [1610/3236], Loss: 2.1614, Perplexity: 8.6836
# Epoch [1/5], Step [1620/3236], Loss: 2.0620, Perplexity: 7.8614
# Epoch [1/5], Step [1630/3236], Loss: 2.2130, Perplexity: 9.1429
# Epoch [1/5], Step [1640/3236], Loss: 2.1494, Perplexity: 8.5800
# Epoch [1/5], Step [1650/3236], Loss: 2.1210, Perplexity: 8.3397
# Epoch [1/5], Step [1660/3236], Loss: 1.9696, Perplexity: 7.1679
# Epoch [1/5], Step [1670/3236], Loss: 2.1330, Perplexity: 8.4398
# Epoch [1/5], Step [1680/3236], Loss: 2.0823, Perplexity: 8.0228
# Epoch [1/5], Step [1690/3236], Loss: 2.2022, Perplexity: 9.0453
# Epoch [1/5], Step [1700/3236], Loss: 2.0243, Perplexity: 7.5708
# Epoch [1/5], Step [1710/3236], Loss: 2.0936, Perplexity: 8.1139
# Epoch [1/5], Step [1720/3236], Loss: 2.0934, Perplexity: 8.1126
# Epoch [1/5], Step [1730/3236], Loss: 2.1518, Perplexity: 8.6006
# Epoch [1/5], Step [1740/3236], Loss: 2.1024, Perplexity: 8.1856
# Epoch [1/5], Step [1750/3236], Loss: 2.1350, Perplexity: 8.4572
# Epoch [1/5], Step [1760/3236], Loss: 1.9892, Perplexity: 7.3097
# Epoch [1/5], Step [1770/3236], Loss: 1.9454, Perplexity: 6.9962
# Epoch [1/5], Step [1780/3236], Loss: 2.1094, Perplexity: 8.2433
# Epoch [1/5], Step [1790/3236], Loss: 1.9843, Perplexity: 7.2738
# Epoch [1/5], Step [1800/3236], Loss: 2.1974, Perplexity: 9.0015
# Epoch [1/5], Step [1810/3236], Loss: 2.1734, Perplexity: 8.7878
# Epoch [1/5], Step [1820/3236], Loss: 2.0450, Perplexity: 7.7293
# Epoch [1/5], Step [1830/3236], Loss: 2.2248, Perplexity: 9.2515
# Epoch [1/5], Step [1840/3236], Loss: 2.0434, Perplexity: 7.7171
# Epoch [1/5], Step [1850/3236], Loss: 2.1436, Perplexity: 8.5304
# Epoch [1/5], Step [1860/3236], Loss: 2.0772, Perplexity: 7.9820
# Epoch [1/5], Step [1870/3236], Loss: 2.1174, Perplexity: 8.3099
# Epoch [1/5], Step [1880/3236], Loss: 2.1156, Perplexity: 8.2948
# Epoch [1/5], Step [1890/3236], Loss: 2.2189, Perplexity: 9.1970
# Epoch [1/5], Step [1900/3236], Loss: 2.0218, Perplexity: 7.5522
# Epoch [1/5], Step [1910/3236], Loss: 2.1581, Perplexity: 8.6544
# Epoch [1/5], Step [1920/3236], Loss: 2.0419, Perplexity: 7.7050
# Epoch [1/5], Step [1930/3236], Loss: 2.2182, Perplexity: 9.1912
# Epoch [1/5], Step [1940/3236], Loss: 2.0640, Perplexity: 7.8770
# Epoch [1/5], Step [1950/3236], Loss: 2.0345, Perplexity: 7.6483
# Epoch [1/5], Step [1960/3236], Loss: 2.0395, Perplexity: 7.6871
# Epoch [1/5], Step [1970/3236], Loss: 2.1572, Perplexity: 8.6465
# Epoch [1/5], Step [1980/3236], Loss: 2.2528, Perplexity: 9.5141
# Epoch [1/5], Step [1990/3236], Loss: 2.2093, Perplexity: 9.1092
# Epoch [1/5], Step [2000/3236], Loss: 2.2365, Perplexity: 9.3609
# Epoch [1/5], Step [2010/3236], Loss: 2.1289, Perplexity: 8.4053
# Epoch [1/5], Step [2020/3236], Loss: 2.1524, Perplexity: 8.6051
# Epoch [1/5], Step [2030/3236], Loss: 2.2464, Perplexity: 9.4540
# Epoch [1/5], Step [2040/3236], Loss: 2.1808, Perplexity: 8.8536
# Epoch [1/5], Step [2050/3236], Loss: 2.0139, Perplexity: 7.4923
# Epoch [1/5], Step [2060/3236], Loss: 2.0117, Perplexity: 7.4758
# Epoch [1/5], Step [2070/3236], Loss: 2.0008, Perplexity: 7.3951
# Epoch [1/5], Step [2080/3236], Loss: 2.0536, Perplexity: 7.7962
# Epoch [1/5], Step [2090/3236], Loss: 2.1008, Perplexity: 8.1723
# Epoch [1/5], Step [2100/3236], Loss: 2.2451, Perplexity: 9.4418
# Epoch [1/5], Step [2110/3236], Loss: 1.9382, Perplexity: 6.9461
# Epoch [1/5], Step [2120/3236], Loss: 2.2165, Perplexity: 9.1751
# Epoch [1/5], Step [2130/3236], Loss: 2.1423, Perplexity: 8.5189
# Epoch [1/5], Step [2140/3236], Loss: 2.1441, Perplexity: 8.5346
# Epoch [1/5], Step [2150/3236], Loss: 2.0122, Perplexity: 7.4798
# Epoch [1/5], Step [2160/3236], Loss: 2.1649, Perplexity: 8.7140
# Epoch [1/5], Step [2170/3236], Loss: 2.1574, Perplexity: 8.6488
# Epoch [1/5], Step [2180/3236], Loss: 2.2136, Perplexity: 9.1487
# Epoch [1/5], Step [2190/3236], Loss: 2.1663, Perplexity: 8.7262
# Epoch [1/5], Step [2200/3236], Loss: 1.9938, Perplexity: 7.3431
# Epoch [1/5], Step [2210/3236], Loss: 2.1285, Perplexity: 8.4023
# Epoch [1/5], Step [2220/3236], Loss: 1.9674, Perplexity: 7.1523
# Epoch [1/5], Step [2230/3236], Loss: 2.1346, Perplexity: 8.4540
# Epoch [1/5], Step [2240/3236], Loss: 2.2551, Perplexity: 9.5358
# Epoch [1/5], Step [2250/3236], Loss: 2.0922, Perplexity: 8.1028
# Epoch [1/5], Step [2260/3236], Loss: 2.1884, Perplexity: 8.9207
# Epoch [1/5], Step [2270/3236], Loss: 2.0794, Perplexity: 7.9998
# Epoch [1/5], Step [2280/3236], Loss: 2.1308, Perplexity: 8.4220
# Epoch [1/5], Step [2290/3236], Loss: 2.0660, Perplexity: 7.8929
# Epoch [1/5], Step [2300/3236], Loss: 2.0570, Perplexity: 7.8224
# Epoch [1/5], Step [2310/3236], Loss: 2.0935, Perplexity: 8.1135
# Epoch [1/5], Step [2320/3236], Loss: 2.2148, Perplexity: 9.1593
# Epoch [1/5], Step [2330/3236], Loss: 2.1609, Perplexity: 8.6786
# Epoch [1/5], Step [2340/3236], Loss: 2.0969, Perplexity: 8.1408
# Epoch [1/5], Step [2350/3236], Loss: 2.1098, Perplexity: 8.2462
# Epoch [1/5], Step [2360/3236], Loss: 1.9835, Perplexity: 7.2683
# Epoch [1/5], Step [2370/3236], Loss: 2.1957, Perplexity: 8.9864
# Epoch [1/5], Step [2380/3236], Loss: 1.9767, Perplexity: 7.2191
# Epoch [1/5], Step [2390/3236], Loss: 2.1822, Perplexity: 8.8658
# Epoch [1/5], Step [2400/3236], Loss: 2.0241, Perplexity: 7.5696
# Epoch [1/5], Step [2410/3236], Loss: 2.0623, Perplexity: 7.8641
# Epoch [1/5], Step [2420/3236], Loss: 2.0644, Perplexity: 7.8803
# Epoch [1/5], Step [2430/3236], Loss: 2.1035, Perplexity: 8.1951
# Epoch [1/5], Step [2440/3236], Loss: 2.1707, Perplexity: 8.7640
# Epoch [1/5], Step [2450/3236], Loss: 2.1434, Perplexity: 8.5283
# Epoch [1/5], Step [2460/3236], Loss: 2.1379, Perplexity: 8.4816
# Epoch [1/5], Step [2470/3236], Loss: 2.1334, Perplexity: 8.4433
# Epoch [1/5], Step [2480/3236], Loss: 1.9404, Perplexity: 6.9615
# Epoch [1/5], Step [2490/3236], Loss: 1.9868, Perplexity: 7.2922
# Epoch [1/5], Step [2500/3236], Loss: 2.1358, Perplexity: 8.4642
# Epoch [1/5], Step [2510/3236], Loss: 2.1613, Perplexity: 8.6823
# Epoch [1/5], Step [2520/3236], Loss: 2.1053, Perplexity: 8.2093
# Epoch [1/5], Step [2530/3236], Loss: 2.1741, Perplexity: 8.7941
# Epoch [1/5], Step [2540/3236], Loss: 2.1117, Perplexity: 8.2619
# Epoch [1/5], Step [2550/3236], Loss: 1.9771, Perplexity: 7.2217
# Epoch [1/5], Step [2560/3236], Loss: 1.9866, Perplexity: 7.2908
# Epoch [1/5], Step [2570/3236], Loss: 2.0315, Perplexity: 7.6259
# Epoch [1/5], Step [2580/3236], Loss: 2.1748, Perplexity: 8.8008
# Epoch [1/5], Step [2590/3236], Loss: 2.0767, Perplexity: 7.9784
# Epoch [1/5], Step [2600/3236], Loss: 2.1062, Perplexity: 8.2172
# Epoch [1/5], Step [2610/3236], Loss: 2.1998, Perplexity: 9.0236
# Epoch [1/5], Step [2620/3236], Loss: 2.1601, Perplexity: 8.6723
# Epoch [1/5], Step [2630/3236], Loss: 2.0429, Perplexity: 7.7129
# Epoch [1/5], Step [2640/3236], Loss: 2.1620, Perplexity: 8.6886
# Epoch [1/5], Step [2650/3236], Loss: 2.0867, Perplexity: 8.0583
# Epoch [1/5], Step [2660/3236], Loss: 2.1761, Perplexity: 8.8118
# Epoch [1/5], Step [2670/3236], Loss: 2.1528, Perplexity: 8.6093
# Epoch [1/5], Step [2680/3236], Loss: 2.0823, Perplexity: 8.0231
# Epoch [1/5], Step [2690/3236], Loss: 2.0153, Perplexity: 7.5031
# Epoch [1/5], Step [2700/3236], Loss: 2.1097, Perplexity: 8.2455
# Epoch [1/5], Step [2710/3236], Loss: 2.0885, Perplexity: 8.0728
# Epoch [1/5], Step [2720/3236], Loss: 2.1490, Perplexity: 8.5761
# Epoch [1/5], Step [2730/3236], Loss: 2.1222, Perplexity: 8.3492
# Epoch [1/5], Step [2740/3236], Loss: 2.0940, Perplexity: 8.1173
# Epoch [1/5], Step [2750/3236], Loss: 2.1598, Perplexity: 8.6693
# Epoch [1/5], Step [2760/3236], Loss: 2.1771, Perplexity: 8.8203
# Epoch [1/5], Step [2770/3236], Loss: 1.9547, Perplexity: 7.0615
# Epoch [1/5], Step [2780/3236], Loss: 2.0143, Perplexity: 7.4957
# Epoch [1/5], Step [2790/3236], Loss: 2.1657, Perplexity: 8.7210
# Epoch [1/5], Step [2800/3236], Loss: 2.1204, Perplexity: 8.3346
# Epoch [1/5], Step [2810/3236], Loss: 2.0801, Perplexity: 8.0056
# Epoch [1/5], Step [2820/3236], Loss: 2.0215, Perplexity: 7.5496
# Epoch [1/5], Step [2830/3236], Loss: 2.0713, Perplexity: 7.9355
# Epoch [1/5], Step [2840/3236], Loss: 2.0234, Perplexity: 7.5636
# Epoch [1/5], Step [2850/3236], Loss: 2.0881, Perplexity: 8.0696
# Epoch [1/5], Step [2860/3236], Loss: 2.1409, Perplexity: 8.5069
# Epoch [1/5], Step [2870/3236], Loss: 2.0968, Perplexity: 8.1402
# Epoch [1/5], Step [2880/3236], Loss: 2.1199, Perplexity: 8.3307
# Epoch [1/5], Step [2890/3236], Loss: 2.0944, Perplexity: 8.1206
# Epoch [1/5], Step [2900/3236], Loss: 2.1164, Perplexity: 8.3009
# Epoch [1/5], Step [2910/3236], Loss: 2.0323, Perplexity: 7.6320
# Epoch [1/5], Step [2920/3236], Loss: 2.0542, Perplexity: 7.8004
# Epoch [1/5], Step [2930/3236], Loss: 2.1077, Perplexity: 8.2293
# Epoch [1/5], Step [2940/3236], Loss: 1.9448, Perplexity: 6.9921
# Epoch [1/5], Step [2950/3236], Loss: 2.0902, Perplexity: 8.0869
# Epoch [1/5], Step [2960/3236], Loss: 2.1687, Perplexity: 8.7468
# Epoch [1/5], Step [2970/3236], Loss: 2.1777, Perplexity: 8.8262
# Epoch [1/5], Step [2980/3236], Loss: 2.0738, Perplexity: 7.9547
# Epoch [1/5], Step [2990/3236], Loss: 2.0750, Perplexity: 7.9642
# Epoch [1/5], Step [3000/3236], Loss: 2.2912, Perplexity: 9.8871
# Epoch [1/5], Step [3010/3236], Loss: 2.1765, Perplexity: 8.8155
# Epoch [1/5], Step [3020/3236], Loss: 2.0700, Perplexity: 7.9249
# Epoch [1/5], Step [3030/3236], Loss: 2.1549, Perplexity: 8.6273
# Epoch [1/5], Step [3040/3236], Loss: 2.0955, Perplexity: 8.1292
# Epoch [1/5], Step [3050/3236], Loss: 2.1674, Perplexity: 8.7356
# Epoch [1/5], Step [3060/3236], Loss: 2.2007, Perplexity: 9.0314
# Epoch [1/5], Step [3070/3236], Loss: 2.0204, Perplexity: 7.5413
# Epoch [1/5], Step [3080/3236], Loss: 2.0364, Perplexity: 7.6630
# Epoch [1/5], Step [3090/3236], Loss: 2.0324, Perplexity: 7.6324
# Epoch [1/5], Step [3100/3236], Loss: 2.0310, Perplexity: 7.6213
# Epoch [1/5], Step [3110/3236], Loss: 2.0605, Perplexity: 7.8496
# Epoch [1/5], Step [3120/3236], Loss: 2.0634, Perplexity: 7.8726
# Epoch [1/5], Step [3130/3236], Loss: 2.1309, Perplexity: 8.4227
# Epoch [1/5], Step [3140/3236], Loss: 2.1101, Perplexity: 8.2493
# Epoch [1/5], Step [3150/3236], Loss: 2.0559, Perplexity: 7.8135
# Epoch [1/5], Step [3160/3236], Loss: 2.0673, Perplexity: 7.9032
# Epoch [1/5], Step [3170/3236], Loss: 2.1649, Perplexity: 8.7136
# Epoch [1/5], Step [3180/3236], Loss: 1.9842, Perplexity: 7.2736
# Epoch [1/5], Step [3190/3236], Loss: 2.0721, Perplexity: 7.9414
# Epoch [1/5], Step [3200/3236], Loss: 1.9808, Perplexity: 7.2487
# Epoch [1/5], Step [3210/3236], Loss: 2.2145, Perplexity: 9.1565
# Epoch [1/5], Step [3220/3236], Loss: 2.0340, Perplexity: 7.6446
# Epoch [1/5], Step [3230/3236], Loss: 2.0927, Perplexity: 8.1069
# Epoch [2/5], Step [0/3236], Loss: 2.0536, Perplexity: 7.7962
# Epoch [2/5], Step [10/3236], Loss: 1.8445, Perplexity: 6.3248
# Epoch [2/5], Step [20/3236], Loss: 1.9400, Perplexity: 6.9587
# Epoch [2/5], Step [30/3236], Loss: 1.9551, Perplexity: 7.0649
# Epoch [2/5], Step [40/3236], Loss: 2.0143, Perplexity: 7.4956
# Epoch [2/5], Step [50/3236], Loss: 2.0346, Perplexity: 7.6493
# Epoch [2/5], Step [60/3236], Loss: 1.9009, Perplexity: 6.6922
# Epoch [2/5], Step [70/3236], Loss: 1.9561, Perplexity: 7.0715
# Epoch [2/5], Step [80/3236], Loss: 2.0036, Perplexity: 7.4159
# Epoch [2/5], Step [90/3236], Loss: 2.0522, Perplexity: 7.7853
# Epoch [2/5], Step [100/3236], Loss: 1.8794, Perplexity: 6.5498
# Epoch [2/5], Step [110/3236], Loss: 2.0708, Perplexity: 7.9314
# Epoch [2/5], Step [120/3236], Loss: 2.0707, Perplexity: 7.9302
# Epoch [2/5], Step [130/3236], Loss: 1.9982, Perplexity: 7.3758
# Epoch [2/5], Step [140/3236], Loss: 1.9881, Perplexity: 7.3019
# Epoch [2/5], Step [150/3236], Loss: 1.9396, Perplexity: 6.9561
# Epoch [2/5], Step [160/3236], Loss: 1.9808, Perplexity: 7.2486
# Epoch [2/5], Step [170/3236], Loss: 1.9207, Perplexity: 6.8260
# Epoch [2/5], Step [180/3236], Loss: 1.8263, Perplexity: 6.2107
# Epoch [2/5], Step [190/3236], Loss: 1.9536, Perplexity: 7.0543
# Epoch [2/5], Step [200/3236], Loss: 2.0919, Perplexity: 8.1001
# Epoch [2/5], Step [210/3236], Loss: 2.0557, Perplexity: 7.8126
# Epoch [2/5], Step [220/3236], Loss: 1.9276, Perplexity: 6.8727
# Epoch [2/5], Step [230/3236], Loss: 2.0033, Perplexity: 7.4137
# Epoch [2/5], Step [240/3236], Loss: 2.0273, Perplexity: 7.5935
# Epoch [2/5], Step [250/3236], Loss: 1.9949, Perplexity: 7.3513
# Epoch [2/5], Step [260/3236], Loss: 2.0127, Perplexity: 7.4832
# Epoch [2/5], Step [270/3236], Loss: 2.0756, Perplexity: 7.9690
# Epoch [2/5], Step [280/3236], Loss: 1.9484, Perplexity: 7.0174
# Epoch [2/5], Step [290/3236], Loss: 1.9904, Perplexity: 7.3184
# Epoch [2/5], Step [300/3236], Loss: 1.9554, Perplexity: 7.0665
# Epoch [2/5], Step [310/3236], Loss: 1.9385, Perplexity: 6.9480
# Epoch [2/5], Step [320/3236], Loss: 2.0285, Perplexity: 7.6023
# Epoch [2/5], Step [330/3236], Loss: 1.8740, Perplexity: 6.5144
# Epoch [2/5], Step [340/3236], Loss: 1.8865, Perplexity: 6.5960
# Epoch [2/5], Step [350/3236], Loss: 2.0569, Perplexity: 7.8217
# Epoch [2/5], Step [360/3236], Loss: 1.9829, Perplexity: 7.2635
# Epoch [2/5], Step [370/3236], Loss: 2.0916, Perplexity: 8.0982
# Epoch [2/5], Step [380/3236], Loss: 1.8935, Perplexity: 6.6426
# Epoch [2/5], Step [390/3236], Loss: 1.9933, Perplexity: 7.3394
# Epoch [2/5], Step [400/3236], Loss: 2.1274, Perplexity: 8.3927
# Epoch [2/5], Step [410/3236], Loss: 2.0142, Perplexity: 7.4946
# Epoch [2/5], Step [420/3236], Loss: 1.8473, Perplexity: 6.3425
# Epoch [2/5], Step [430/3236], Loss: 1.9891, Perplexity: 7.3093
# Epoch [2/5], Step [440/3236], Loss: 2.0141, Perplexity: 7.4940
# Epoch [2/5], Step [450/3236], Loss: 2.0368, Perplexity: 7.6663
# Epoch [2/5], Step [460/3236], Loss: 2.1470, Perplexity: 8.5591
# Epoch [2/5], Step [470/3236], Loss: 2.0151, Perplexity: 7.5015
# Epoch [2/5], Step [480/3236], Loss: 1.9840, Perplexity: 7.2718
# Epoch [2/5], Step [490/3236], Loss: 2.1605, Perplexity: 8.6756
# Epoch [2/5], Step [500/3236], Loss: 1.9980, Perplexity: 7.3743
# Epoch [2/5], Step [510/3236], Loss: 2.0394, Perplexity: 7.6857
# Epoch [2/5], Step [520/3236], Loss: 1.9941, Perplexity: 7.3454
# Epoch [2/5], Step [530/3236], Loss: 1.9727, Perplexity: 7.1899
# Epoch [2/5], Step [540/3236], Loss: 1.9057, Perplexity: 6.7240
# Epoch [2/5], Step [550/3236], Loss: 1.9832, Perplexity: 7.2657
# Epoch [2/5], Step [560/3236], Loss: 2.0335, Perplexity: 7.6407
# Epoch [2/5], Step [570/3236], Loss: 1.8433, Perplexity: 6.3174
# Epoch [2/5], Step [580/3236], Loss: 1.9110, Perplexity: 6.7599
# Epoch [2/5], Step [590/3236], Loss: 2.0630, Perplexity: 7.8697
# Epoch [2/5], Step [600/3236], Loss: 2.0655, Perplexity: 7.8895
# Epoch [2/5], Step [610/3236], Loss: 1.9888, Perplexity: 7.3068
# Epoch [2/5], Step [620/3236], Loss: 2.0970, Perplexity: 8.1420
# Epoch [2/5], Step [630/3236], Loss: 1.9272, Perplexity: 6.8699
# Epoch [2/5], Step [640/3236], Loss: 1.9868, Perplexity: 7.2923
# Epoch [2/5], Step [650/3236], Loss: 2.0016, Perplexity: 7.4011
# Epoch [2/5], Step [660/3236], Loss: 2.0097, Perplexity: 7.4607
# Epoch [2/5], Step [670/3236], Loss: 1.8503, Perplexity: 6.3619
# Epoch [2/5], Step [680/3236], Loss: 1.9288, Perplexity: 6.8815
# Epoch [2/5], Step [690/3236], Loss: 2.1038, Perplexity: 8.1971
# Epoch [2/5], Step [700/3236], Loss: 1.9952, Perplexity: 7.3540
# Epoch [2/5], Step [710/3236], Loss: 1.9516, Perplexity: 7.0398
# Epoch [2/5], Step [720/3236], Loss: 1.9721, Perplexity: 7.1854
# Epoch [2/5], Step [730/3236], Loss: 2.0704, Perplexity: 7.9279
# Epoch [2/5], Step [740/3236], Loss: 1.9498, Perplexity: 7.0270
# Epoch [2/5], Step [750/3236], Loss: 2.0184, Perplexity: 7.5263
# Epoch [2/5], Step [760/3236], Loss: 1.9402, Perplexity: 6.9599
# Epoch [2/5], Step [770/3236], Loss: 2.0383, Perplexity: 7.6778
# Epoch [2/5], Step [780/3236], Loss: 2.0054, Perplexity: 7.4294
# Epoch [2/5], Step [790/3236], Loss: 1.9030, Perplexity: 6.7058
# Epoch [2/5], Step [800/3236], Loss: 1.9532, Perplexity: 7.0514
# Epoch [2/5], Step [810/3236], Loss: 2.1337, Perplexity: 8.4463
# Epoch [2/5], Step [820/3236], Loss: 1.9252, Perplexity: 6.8564
# Epoch [2/5], Step [830/3236], Loss: 2.1215, Perplexity: 8.3435
# Epoch [2/5], Step [840/3236], Loss: 2.0533, Perplexity: 7.7936
# Epoch [2/5], Step [850/3236], Loss: 1.9595, Perplexity: 7.0957
# Epoch [2/5], Step [860/3236], Loss: 1.9085, Perplexity: 6.7431
# Epoch [2/5], Step [870/3236], Loss: 2.1089, Perplexity: 8.2391
# Epoch [2/5], Step [880/3236], Loss: 2.0472, Perplexity: 7.7459
# Epoch [2/5], Step [890/3236], Loss: 1.9873, Perplexity: 7.2957
# Epoch [2/5], Step [900/3236], Loss: 1.9830, Perplexity: 7.2645
# Epoch [2/5], Step [910/3236], Loss: 1.9635, Perplexity: 7.1241
# Epoch [2/5], Step [920/3236], Loss: 2.0580, Perplexity: 7.8303
# Epoch [2/5], Step [930/3236], Loss: 2.0198, Perplexity: 7.5367
# Epoch [2/5], Step [940/3236], Loss: 2.0734, Perplexity: 7.9520
# Epoch [2/5], Step [950/3236], Loss: 1.9535, Perplexity: 7.0535
# Epoch [2/5], Step [960/3236], Loss: 1.9716, Perplexity: 7.1825
# Epoch [2/5], Step [970/3236], Loss: 2.0156, Perplexity: 7.5052
# ...
# Epoch [4/5], Step [740/3236], Loss: 1.8802, Perplexity: 6.5551
# Epoch [4/5], Step [750/3236], Loss: 1.8575, Perplexity: 6.4075
# Epoch [4/5], Step [760/3236], Loss: 1.9092, Perplexity: 6.7475
# Epoch [4/5], Step [770/3236], Loss: 1.8424, Perplexity: 6.3118
# Epoch [4/5], Step [780/3236], Loss: 1.8557, Perplexity: 6.3964
# Epoch [4/5], Step [790/3236], Loss: 1.6971, Perplexity: 5.4582
# Epoch [4/5], Step [800/3236], Loss: 1.7727, Perplexity: 5.8869
# Epoch [4/5], Step [810/3236], Loss: 1.8699, Perplexity: 6.4880
# Epoch [4/5], Step [820/3236], Loss: 1.8635, Perplexity: 6.4462
# Epoch [4/5], Step [830/3236], Loss: 1.8313, Perplexity: 6.2420
# Epoch [4/5], Step [840/3236], Loss: 1.8808, Perplexity: 6.5590
# Epoch [4/5], Step [850/3236], Loss: 1.7771, Perplexity: 5.9128
# Epoch [4/5], Step [860/3236], Loss: 1.7778, Perplexity: 5.9170
# Epoch [4/5], Step [870/3236], Loss: 1.8040, Perplexity: 6.0737
# Epoch [4/5], Step [880/3236], Loss: 1.7912, Perplexity: 5.9968
# Epoch [4/5], Step [890/3236], Loss: 1.8166, Perplexity: 6.1510
# Epoch [4/5], Step [900/3236], Loss: 1.7821, Perplexity: 5.9420
# Epoch [4/5], Step [910/3236], Loss: 1.8531, Perplexity: 6.3795
# Epoch [4/5], Step [920/3236], Loss: 1.8845, Perplexity: 6.5829
# Epoch [4/5], Step [930/3236], Loss: 1.8109, Perplexity: 6.1158
# Epoch [4/5], Step [940/3236], Loss: 1.7879, Perplexity: 5.9769
# Epoch [4/5], Step [950/3236], Loss: 1.7592, Perplexity: 5.8076
# Epoch [4/5], Step [960/3236], Loss: 1.9300, Perplexity: 6.8897
# Epoch [4/5], Step [970/3236], Loss: 1.9181, Perplexity: 6.8077
# Epoch [4/5], Step [980/3236], Loss: 1.8643, Perplexity: 6.4512
# Epoch [4/5], Step [990/3236], Loss: 1.8999, Perplexity: 6.6853
# Epoch [4/5], Step [1000/3236], Loss: 1.8649, Perplexity: 6.4551
# Epoch [4/5], Step [1010/3236], Loss: 1.7923, Perplexity: 6.0034
# Epoch [4/5], Step [1020/3236], Loss: 1.8835, Perplexity: 6.5767
# Epoch [4/5], Step [1030/3236], Loss: 1.9006, Perplexity: 6.6897
# Epoch [4/5], Step [1040/3236], Loss: 1.8196, Perplexity: 6.1692
# Epoch [4/5], Step [1050/3236], Loss: 1.9505, Perplexity: 7.0322
# Epoch [4/5], Step [1060/3236], Loss: 1.8055, Perplexity: 6.0832
# Epoch [4/5], Step [1070/3236], Loss: 1.8481, Perplexity: 6.3477
# Epoch [4/5], Step [1080/3236], Loss: 1.7270, Perplexity: 5.6240
# Epoch [4/5], Step [1090/3236], Loss: 1.8248, Perplexity: 6.2018
# Epoch [4/5], Step [1100/3236], Loss: 1.9676, Perplexity: 7.1533
# Epoch [4/5], Step [1110/3236], Loss: 1.9198, Perplexity: 6.8198
# Epoch [4/5], Step [1120/3236], Loss: 1.7782, Perplexity: 5.9195
# Epoch [4/5], Step [1130/3236], Loss: 1.8662, Perplexity: 6.4638
# Epoch [4/5], Step [1140/3236], Loss: 1.9203, Perplexity: 6.8227
# Epoch [4/5], Step [1150/3236], Loss: 1.9206, Perplexity: 6.8253
# Epoch [4/5], Step [1160/3236], Loss: 1.9035, Perplexity: 6.7091
# Epoch [4/5], Step [1170/3236], Loss: 1.8094, Perplexity: 6.1069
# Epoch [4/5], Step [1180/3236], Loss: 1.7972, Perplexity: 6.0328
# Epoch [4/5], Step [1190/3236], Loss: 1.9103, Perplexity: 6.7552
# Epoch [4/5], Step [1200/3236], Loss: 1.7787, Perplexity: 5.9224
# Epoch [4/5], Step [1210/3236], Loss: 1.9865, Perplexity: 7.2903
# Epoch [4/5], Step [1220/3236], Loss: 1.9236, Perplexity: 6.8453
# Epoch [4/5], Step [1230/3236], Loss: 1.8503, Perplexity: 6.3619
# Epoch [4/5], Step [1240/3236], Loss: 1.9220, Perplexity: 6.8344
# Epoch [4/5], Step [1250/3236], Loss: 1.7116, Perplexity: 5.5375
# Epoch [4/5], Step [1260/3236], Loss: 1.7730, Perplexity: 5.8882
# Epoch [4/5], Step [1270/3236], Loss: 1.8675, Perplexity: 6.4723
# Epoch [4/5], Step [1280/3236], Loss: 1.9084, Perplexity: 6.7425
# Epoch [4/5], Step [1290/3236], Loss: 1.8651, Perplexity: 6.4564
# Epoch [4/5], Step [1300/3236], Loss: 1.7857, Perplexity: 5.9636
# Epoch [4/5], Step [1310/3236], Loss: 1.8251, Perplexity: 6.2035
# Epoch [4/5], Step [1320/3236], Loss: 1.6955, Perplexity: 5.4492
# Epoch [4/5], Step [1330/3236], Loss: 1.8214, Perplexity: 6.1804
# Epoch [4/5], Step [1340/3236], Loss: 1.6982, Perplexity: 5.4643
# Epoch [4/5], Step [1350/3236], Loss: 1.8014, Perplexity: 6.0579
# Epoch [4/5], Step [1360/3236], Loss: 1.8749, Perplexity: 6.5201
# Epoch [4/5], Step [1370/3236], Loss: 1.9040, Perplexity: 6.7125
# Epoch [4/5], Step [1380/3236], Loss: 1.9095, Perplexity: 6.7499
# Epoch [4/5], Step [1390/3236], Loss: 1.7295, Perplexity: 5.6380
# Epoch [4/5], Step [1400/3236], Loss: 1.8433, Perplexity: 6.3174
# Epoch [4/5], Step [1410/3236], Loss: 1.8232, Perplexity: 6.1918
# Epoch [4/5], Step [1420/3236], Loss: 1.8075, Perplexity: 6.0949
# Epoch [4/5], Step [1430/3236], Loss: 1.9050, Perplexity: 6.7197
# Epoch [4/5], Step [1440/3236], Loss: 1.8603, Perplexity: 6.4258
# Epoch [4/5], Step [1450/3236], Loss: 1.8849, Perplexity: 6.5856
# Epoch [4/5], Step [1460/3236], Loss: 1.8046, Perplexity: 6.0776
# Epoch [4/5], Step [1470/3236], Loss: 1.8689, Perplexity: 6.4809
# Epoch [4/5], Step [1480/3236], Loss: 1.8347, Perplexity: 6.2632
# Epoch [4/5], Step [1490/3236], Loss: 1.7633, Perplexity: 5.8314
# Epoch [4/5], Step [1500/3236], Loss: 1.7998, Perplexity: 6.0483
# Epoch [4/5], Step [1510/3236], Loss: 1.9081, Perplexity: 6.7403
# Epoch [4/5], Step [1520/3236], Loss: 1.8952, Perplexity: 6.6537
# Epoch [4/5], Step [1530/3236], Loss: 1.9387, Perplexity: 6.9496
# Epoch [4/5], Step [1540/3236], Loss: 1.8374, Perplexity: 6.2801
# Epoch [4/5], Step [1550/3236], Loss: 1.8791, Perplexity: 6.5474
# Epoch [4/5], Step [1560/3236], Loss: 1.8802, Perplexity: 6.5549
# Epoch [4/5], Step [1570/3236], Loss: 1.9141, Perplexity: 6.7810
# Epoch [4/5], Step [1580/3236], Loss: 1.8532, Perplexity: 6.3801
# Epoch [4/5], Step [1590/3236], Loss: 1.8503, Perplexity: 6.3614
# Epoch [4/5], Step [1600/3236], Loss: 1.8688, Perplexity: 6.4808
# Epoch [4/5], Step [1610/3236], Loss: 1.8411, Perplexity: 6.3036
# Epoch [4/5], Step [1620/3236], Loss: 1.9154, Perplexity: 6.7900
# Epoch [4/5], Step [1630/3236], Loss: 1.9423, Perplexity: 6.9746
# Epoch [4/5], Step [1640/3236], Loss: 1.8003, Perplexity: 6.0515
# Epoch [4/5], Step [1650/3236], Loss: 1.9155, Perplexity: 6.7907
# Epoch [4/5], Step [1660/3236], Loss: 1.8598, Perplexity: 6.4222
# Epoch [4/5], Step [1670/3236], Loss: 1.7670, Perplexity: 5.8531
# Epoch [4/5], Step [1680/3236], Loss: 1.8176, Perplexity: 6.1571
# Epoch [4/5], Step [1690/3236], Loss: 1.7911, Perplexity: 5.9962
# Epoch [4/5], Step [1700/3236], Loss: 1.8125, Perplexity: 6.1260
# Epoch [4/5], Step [1710/3236], Loss: 1.8630, Perplexity: 6.4429
# Epoch [4/5], Step [1720/3236], Loss: 1.9330, Perplexity: 6.9101
# Epoch [4/5], Step [1730/3236], Loss: 1.9529, Perplexity: 7.0488
# Epoch [4/5], Step [1740/3236], Loss: 1.7755, Perplexity: 5.9032
# Epoch [4/5], Step [1750/3236], Loss: 1.7955, Perplexity: 6.0225
# Epoch [4/5], Step [1760/3236], Loss: 1.9091, Perplexity: 6.7468
# Epoch [4/5], Step [1770/3236], Loss: 1.8360, Perplexity: 6.2715
# Epoch [4/5], Step [1780/3236], Loss: 1.8768, Perplexity: 6.5329
# Epoch [4/5], Step [1790/3236], Loss: 1.7808, Perplexity: 5.9349
# Epoch [4/5], Step [1800/3236], Loss: 1.9137, Perplexity: 6.7778
# Epoch [4/5], Step [1810/3236], Loss: 1.8432, Perplexity: 6.3164
# Epoch [4/5], Step [1820/3236], Loss: 1.9144, Perplexity: 6.7827
# Epoch [4/5], Step [1830/3236], Loss: 1.8387, Perplexity: 6.2881
# Epoch [4/5], Step [1840/3236], Loss: 1.7435, Perplexity: 5.7171
# Epoch [4/5], Step [1850/3236], Loss: 1.8538, Perplexity: 6.3841
# Epoch [4/5], Step [1860/3236], Loss: 1.8793, Perplexity: 6.5489
# Epoch [4/5], Step [1870/3236], Loss: 1.7745, Perplexity: 5.8976
# Epoch [4/5], Step [1880/3236], Loss: 1.8933, Perplexity: 6.6414
# Epoch [4/5], Step [1890/3236], Loss: 1.8046, Perplexity: 6.0774
# Epoch [4/5], Step [1900/3236], Loss: 1.7746, Perplexity: 5.8980
# Epoch [4/5], Step [1910/3236], Loss: 1.9457, Perplexity: 6.9985
# Epoch [4/5], Step [1920/3236], Loss: 1.8320, Perplexity: 6.2461
# Epoch [4/5], Step [1930/3236], Loss: 1.8920, Perplexity: 6.6323
# Epoch [4/5], Step [1940/3236], Loss: 1.9632, Perplexity: 7.1220
# Epoch [4/5], Step [1950/3236], Loss: 1.9268, Perplexity: 6.8678
# Epoch [4/5], Step [1960/3236], Loss: 1.9165, Perplexity: 6.7970
# Epoch [4/5], Step [1970/3236], Loss: 1.9127, Perplexity: 6.7714
# Epoch [4/5], Step [1980/3236], Loss: 1.8553, Perplexity: 6.3936
# Epoch [4/5], Step [1990/3236], Loss: 1.7902, Perplexity: 5.9907
# Epoch [4/5], Step [2000/3236], Loss: 1.8317, Perplexity: 6.2448
# Epoch [4/5], Step [2010/3236], Loss: 1.8693, Perplexity: 6.4836
# Epoch [4/5], Step [2020/3236], Loss: 1.8562, Perplexity: 6.3995
# Epoch [4/5], Step [2030/3236], Loss: 1.9086, Perplexity: 6.7437
# Epoch [4/5], Step [2040/3236], Loss: 1.9320, Perplexity: 6.9033
# Epoch [4/5], Step [2050/3236], Loss: 1.9243, Perplexity: 6.8500
# Epoch [4/5], Step [2060/3236], Loss: 1.7352, Perplexity: 5.6702
# Epoch [4/5], Step [2070/3236], Loss: 1.9810, Perplexity: 7.2501
# Epoch [4/5], Step [2080/3236], Loss: 1.8726, Perplexity: 6.5053
# Epoch [4/5], Step [2090/3236], Loss: 1.9732, Perplexity: 7.1937
# Epoch [4/5], Step [2100/3236], Loss: 1.9656, Perplexity: 7.1389
# Epoch [4/5], Step [2110/3236], Loss: 1.9068, Perplexity: 6.7314
# Epoch [4/5], Step [2120/3236], Loss: 1.7984, Perplexity: 6.0401
# Epoch [4/5], Step [2130/3236], Loss: 1.7759, Perplexity: 5.9059
# Epoch [4/5], Step [2140/3236], Loss: 2.0382, Perplexity: 7.6770
# Epoch [4/5], Step [2150/3236], Loss: 1.8951, Perplexity: 6.6529
# Epoch [4/5], Step [2160/3236], Loss: 1.8580, Perplexity: 6.4109
# Epoch [4/5], Step [2170/3236], Loss: 1.8012, Perplexity: 6.0567
# Epoch [4/5], Step [2180/3236], Loss: 1.8718, Perplexity: 6.5000
# Epoch [4/5], Step [2190/3236], Loss: 1.8413, Perplexity: 6.3050
# Epoch [4/5], Step [2200/3236], Loss: 1.8452, Perplexity: 6.3291
# Epoch [4/5], Step [2210/3236], Loss: 1.9648, Perplexity: 7.1337
# Epoch [4/5], Step [2220/3236], Loss: 1.8477, Perplexity: 6.3452
# Epoch [4/5], Step [2230/3236], Loss: 1.9194, Perplexity: 6.8168
# Epoch [4/5], Step [2240/3236], Loss: 1.8682, Perplexity: 6.4767
# Epoch [4/5], Step [2250/3236], Loss: 1.7755, Perplexity: 5.9034
# Epoch [4/5], Step [2260/3236], Loss: 1.8835, Perplexity: 6.5767
# Epoch [4/5], Step [2270/3236], Loss: 1.8992, Perplexity: 6.6808
# Epoch [4/5], Step [2280/3236], Loss: 1.7696, Perplexity: 5.8684
# Epoch [4/5], Step [2290/3236], Loss: 1.8390, Perplexity: 6.2905
# Epoch [4/5], Step [2300/3236], Loss: 1.9158, Perplexity: 6.7924
# Epoch [4/5], Step [2310/3236], Loss: 1.8848, Perplexity: 6.5850
# Epoch [4/5], Step [2320/3236], Loss: 1.7965, Perplexity: 6.0285
# Epoch [4/5], Step [2330/3236], Loss: 1.8864, Perplexity: 6.5959
# Epoch [4/5], Step [2340/3236], Loss: 1.9355, Perplexity: 6.9276
# Epoch [4/5], Step [2350/3236], Loss: 1.7887, Perplexity: 5.9816
# Epoch [4/5], Step [2360/3236], Loss: 1.8397, Perplexity: 6.2950
# Epoch [4/5], Step [2370/3236], Loss: 1.8463, Perplexity: 6.3363
# Epoch [4/5], Step [2380/3236], Loss: 1.9256, Perplexity: 6.8590
# Epoch [4/5], Step [2390/3236], Loss: 1.7569, Perplexity: 5.7942
# Epoch [4/5], Step [2400/3236], Loss: 1.8125, Perplexity: 6.1257
# Epoch [4/5], Step [2410/3236], Loss: 1.9027, Perplexity: 6.7038
# Epoch [4/5], Step [2420/3236], Loss: 1.8609, Perplexity: 6.4296
# Epoch [4/5], Step [2430/3236], Loss: 1.8765, Perplexity: 6.5308
# Epoch [4/5], Step [2440/3236], Loss: 1.8415, Perplexity: 6.3063
# Epoch [4/5], Step [2450/3236], Loss: 1.8912, Perplexity: 6.6274
# Epoch [4/5], Step [2460/3236], Loss: 1.8169, Perplexity: 6.1528
# Epoch [4/5], Step [2470/3236], Loss: 1.8397, Perplexity: 6.2948
# Epoch [4/5], Step [2480/3236], Loss: 1.8532, Perplexity: 6.3805
# Epoch [4/5], Step [2490/3236], Loss: 1.7414, Perplexity: 5.7051
# Epoch [4/5], Step [2500/3236], Loss: 1.7500, Perplexity: 5.7547
# Epoch [4/5], Step [2510/3236], Loss: 1.9138, Perplexity: 6.7787
# Epoch [4/5], Step [2520/3236], Loss: 2.0427, Perplexity: 7.7113
# Epoch [4/5], Step [2530/3236], Loss: 1.8624, Perplexity: 6.4391
# Epoch [4/5], Step [2540/3236], Loss: 1.9695, Perplexity: 7.1671
# Epoch [4/5], Step [2550/3236], Loss: 1.8072, Perplexity: 6.0935
# Epoch [4/5], Step [2560/3236], Loss: 1.8310, Perplexity: 6.2403
# Epoch [4/5], Step [2570/3236], Loss: 1.8651, Perplexity: 6.4563
# Epoch [4/5], Step [2580/3236], Loss: 1.7829, Perplexity: 5.9471
# Epoch [4/5], Step [2590/3236], Loss: 1.9026, Perplexity: 6.7030
# Epoch [4/5], Step [2600/3236], Loss: 1.9143, Perplexity: 6.7822
# Epoch [4/5], Step [2610/3236], Loss: 1.8261, Perplexity: 6.2095
# Epoch [4/5], Step [2620/3236], Loss: 1.8891, Perplexity: 6.6136
# Epoch [4/5], Step [2630/3236], Loss: 1.8211, Perplexity: 6.1787
# Epoch [4/5], Step [2640/3236], Loss: 1.8218, Perplexity: 6.1828
# Epoch [4/5], Step [2650/3236], Loss: 1.8551, Perplexity: 6.3921
# Epoch [4/5], Step [2660/3236], Loss: 1.7788, Perplexity: 5.9230
# Epoch [4/5], Step [2670/3236], Loss: 1.8547, Perplexity: 6.3900
# Epoch [4/5], Step [2680/3236], Loss: 1.9063, Perplexity: 6.7284
# Epoch [4/5], Step [2690/3236], Loss: 1.8313, Perplexity: 6.2420
# Epoch [4/5], Step [2700/3236], Loss: 1.9117, Perplexity: 6.7647
# Epoch [4/5], Step [2710/3236], Loss: 1.9010, Perplexity: 6.6927
# Epoch [4/5], Step [2720/3236], Loss: 1.8568, Perplexity: 6.4035
# Epoch [4/5], Step [2730/3236], Loss: 1.8518, Perplexity: 6.3711
# Epoch [4/5], Step [2740/3236], Loss: 1.8986, Perplexity: 6.6765
# Epoch [4/5], Step [2750/3236], Loss: 1.9154, Perplexity: 6.7896
# Epoch [4/5], Step [2760/3236], Loss: 1.9067, Perplexity: 6.7310
# Epoch [4/5], Step [2770/3236], Loss: 1.8715, Perplexity: 6.4983
# Epoch [4/5], Step [2780/3236], Loss: 1.7733, Perplexity: 5.8902
# Epoch [4/5], Step [2790/3236], Loss: 1.8820, Perplexity: 6.5668
# Epoch [4/5], Step [2800/3236], Loss: 1.8708, Perplexity: 6.4935
# Epoch [4/5], Step [2810/3236], Loss: 1.8772, Perplexity: 6.5350
# Epoch [4/5], Step [2820/3236], Loss: 1.9311, Perplexity: 6.8971
# Epoch [4/5], Step [2830/3236], Loss: 1.8923, Perplexity: 6.6348
# Epoch [4/5], Step [2840/3236], Loss: 1.8481, Perplexity: 6.3476
# Epoch [4/5], Step [2850/3236], Loss: 1.8001, Perplexity: 6.0501
# Epoch [4/5], Step [2860/3236], Loss: 1.9722, Perplexity: 7.1863
# Epoch [4/5], Step [2870/3236], Loss: 1.9009, Perplexity: 6.6921
# Epoch [4/5], Step [2880/3236], Loss: 1.9093, Perplexity: 6.7481
# Epoch [4/5], Step [2890/3236], Loss: 1.8688, Perplexity: 6.4807
# Epoch [4/5], Step [2900/3236], Loss: 1.9099, Perplexity: 6.7527
# Epoch [4/5], Step [2910/3236], Loss: 1.9310, Perplexity: 6.8962
# Epoch [4/5], Step [2920/3236], Loss: 1.8658, Perplexity: 6.4614
# Epoch [4/5], Step [2930/3236], Loss: 1.8617, Perplexity: 6.4344
# Epoch [4/5], Step [2940/3236], Loss: 1.7959, Perplexity: 6.0249
# Epoch [4/5], Step [2950/3236], Loss: 1.8537, Perplexity: 6.3836
# Epoch [4/5], Step [2960/3236], Loss: 1.9279, Perplexity: 6.8753
# Epoch [4/5], Step [2970/3236], Loss: 1.9760, Perplexity: 7.2138
# Epoch [4/5], Step [2980/3236], Loss: 1.9794, Perplexity: 7.2387
# Epoch [4/5], Step [2990/3236], Loss: 1.9023, Perplexity: 6.7013
# Epoch [4/5], Step [3000/3236], Loss: 1.8884, Perplexity: 6.6091
# Epoch [4/5], Step [3010/3236], Loss: 1.8557, Perplexity: 6.3963
# Epoch [4/5], Step [3020/3236], Loss: 1.8898, Perplexity: 6.6181
# Epoch [4/5], Step [3030/3236], Loss: 1.9140, Perplexity: 6.7805
# Epoch [4/5], Step [3040/3236], Loss: 1.8313, Perplexity: 6.2419
# Epoch [4/5], Step [3050/3236], Loss: 1.8729, Perplexity: 6.5074
# Epoch [4/5], Step [3060/3236], Loss: 1.7827, Perplexity: 5.9458
# Epoch [4/5], Step [3070/3236], Loss: 1.8371, Perplexity: 6.2786
# Epoch [4/5], Step [3080/3236], Loss: 1.7846, Perplexity: 5.9575
# Epoch [4/5], Step [3090/3236], Loss: 1.8590, Perplexity: 6.4172
# Epoch [4/5], Step [3100/3236], Loss: 1.8768, Perplexity: 6.5325
# Epoch [4/5], Step [3110/3236], Loss: 1.8385, Perplexity: 6.2873
# Epoch [4/5], Step [3120/3236], Loss: 1.8275, Perplexity: 6.2182
# Epoch [4/5], Step [3130/3236], Loss: 1.8832, Perplexity: 6.5748
# Epoch [4/5], Step [3140/3236], Loss: 1.9740, Perplexity: 7.1996
# Epoch [4/5], Step [3150/3236], Loss: 1.8975, Perplexity: 6.6693
# Epoch [4/5], Step [3160/3236], Loss: 1.7929, Perplexity: 6.0067
# Epoch [4/5], Step [3170/3236], Loss: 1.8552, Perplexity: 6.3929
# Epoch [4/5], Step [3180/3236], Loss: 1.7950, Perplexity: 6.0194
# Epoch [4/5], Step [3190/3236], Loss: 1.8474, Perplexity: 6.3435
# Epoch [4/5], Step [3200/3236], Loss: 1.8308, Perplexity: 6.2390
# Epoch [4/5], Step [3210/3236], Loss: 1.7878, Perplexity: 5.9761
# Epoch [4/5], Step [3220/3236], Loss: 1.8953, Perplexity: 6.6547
# Epoch [4/5], Step [3230/3236], Loss: 1.7869, Perplexity: 5.9708

# %% [markdown]
# ## predict caption

# %%
image_file_path = './data/coco/COCO_val2014_000000581632.jpg' 
#image_file_path = './data/coco/sample.jpg' 
 

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
 

def load_image(image_file_path, transform=None):
    img = Image.open(image_file_path).convert('RGB')
    img = img.resize([224, 224], Image.LANCZOS)
    
    if transform is not None:
        img = transform(img).unsqueeze(0)
    
    return img
 

# Image preprocessing
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data/coco/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)


# Build models
encoder_model = CNNModel(256).eval()  # eval mode (batchnorm uses moving mean/variance)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1)
encoder_model = encoder_model.to(device)
decoder_model = decoder_model.to(device)


# Load the trained model parameters
encoder_model.load_state_dict(torch.load('models_dir/encoder-5-3000.ckpt'))
decoder_model.load_state_dict(torch.load('models_dir/decoder-5-3000.ckpt'))


# Prepare an image
img = load_image(image_file_path, transform)
img_tensor = img.to(device)


# Generate an caption from the image
feat = encoder_model(img_tensor)
sampled_indices = decoder_model.sample(feat)
sampled_indices = sampled_indices[0].cpu().numpy()          # (1, max_seq_length) -> (max_seq_length)


# Convert word_ids to words
predicted_caption = []
for token_index in sampled_indices:
    word = vocabulary.i2w[token_index]
    predicted_caption.append(word)
    if word == '<end>':
        break
predicted_sentence = ' '.join(predicted_caption)


# Print out the image and the generated caption
print (predicted_sentence)
img = Image.open(image_file_path)
plt.imshow(np.asarray(img))
# Out:
# <start> a clock hangs from the ceiling in a retail store . <end>

# %%
1
# Out:
# 1

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: Thu Mar 20 2025
#
# Python implementation: CPython
# Python version       : 3.9.19
# IPython version      : 8.18.1
#
# torch      : 2.3.0
# pycocotools: 2.0.7
# torchvision: 0.18.0
# numpy      : 1.26.4
# matplotlib : 3.9.0
# nltk       : 3.9.1
# PIL        : 10.3.0
#
# Watermark: 2.4.3

# %%
torch.__version__
# Out:
# '2.3.0'
